# %%
#Part-1 Video/image feature extraction

# %%
# Modified to process a list of videos
"""Extract features for videos using pre-trained networks"""
from feature_extract.configs.custom_config import load_config
from slowfast.utils.misc import launch_job
from slowfast.utils.parser import parse_args
import numpy as np
import torch
import os
import time
from tqdm import tqdm
import av
from moviepy.video.io.VideoFileClip import VideoFileClip

import slowfast.utils.checkpoint as cu
import slowfast.utils.distributed as du
import slowfast.utils.logging as logging
import slowfast.utils.misc as misc

from feature_extract.models import build_model
from feature_extract.datasets.extract_dataset import VideoSet
import copy
logger = logging.get_logger(__name__)
# Out:
# /data/py/miniconda3/envs/tridet/lib/python3.9/site-packages/torchvision/transforms/_functional_video.py:6: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   warnings.warn(
# /data/py/miniconda3/envs/tridet/lib/python3.9/site-packages/torchvision/transforms/_transforms_video.py:22: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   warnings.warn(

# %%
import os
import random
from io import BytesIO
import torch
import numpy as np
import cv2
from slowfast.datasets.utils import pack_pathway_output
from feature_extract.configs.custom_config import load_config
from slowfast.utils.parser import parse_args
from matplotlib import pyplot as plt
from collections import deque

import argparse
import sys

# %%
#Feature extraction configs
def parse_args():
    """
    Parse the following arguments for a default parser for PySlowFast users.
    Args:
        shard_id (int): shard id for the current machine. Starts from 0 to
            num_shards - 1. If single machine is used, then set shard id to 0.
        num_shards (int): number of shards using by the job.
        init_method (str): initialization method to launch the job with multiple
            devices. Options includes TCP or shared file-system for
            initialization. details can be find in
            https://pytorch.org/docs/stable/distributed.html#tcp-initialization
        cfg (str): path to the config file.
        opts (argument): provide addtional options from the command line, it
            overwrites the config loaded from file.
    """
    parser = argparse.ArgumentParser(
        description="Provide SlowFast video training and testing pipeline."
    )
    parser.add_argument(
        "--shard_id",
        help="The shard id of current node, Starts from 0 to num_shards - 1",
        default=0,
        type=int,
    )
    parser.add_argument(
        "--num_shards",
        help="Number of shards using by the job",
        default=1,
        type=int,
    )
    parser.add_argument(
        "--init_method",
        help="Initialization method, includes TCP or shared file-system",
        default="tcp://localhost:9999",
        type=str,
    )
    parser.add_argument(
        "--cfg",
        dest="cfg_files",
        help="Path to the config files",
        default=["/data/disk/LUO/slowfast/feature_extract/configs/SLOWFAST_8x8_R50_1031.yaml"],
        nargs="+",
    )
    parser.add_argument(
        "--opts",
        help="See slowfast/config/defaults.py for all options",
        default=None,
        nargs=argparse.REMAINDER,
    )
    parser.add_argument(
        "--f",
        help="for jupyternotebook to run",
        default=None,
        nargs=argparse.REMAINDER,
    )
    if len(sys.argv) == 1:
        parser.print_help()
    return parser.parse_args()

# %%
#创建一个steram output feature的方法

# %%
#Feature extraction image process

def pre_process_frame(arr):
        """
        Pre process an array
        Args:
            arr (ndarray): an array of frames of shape T x H x W x C 
        Returns:
            arr (tensor): a normalized torch tensor of shape C x T x H x W 
        """
        arr = torch.from_numpy(arr).float()
        # Normalize the values
        arr = arr / 255.0
        #DATA.MEAN = [0.45, 0.45, 0.45]
        arr = arr - torch.tensor([0.45, 0.45, 0.45])
        #_C.DATA.STD = [0.225, 0.225, 0.225]
        arr = arr / torch.tensor([0.225, 0.225, 0.225])

        # T H W C -> C T H W.
        try:
            arr = arr.permute(3, 0, 1, 2)
        except Exception as e:
            print("length of the array is not T x H x W x C ")

        return arr

# %%
#model(input)的框架

# %%
def calculate_time_taken(start_time, end_time):
    hours = int((end_time - start_time) / 3600)
    minutes = int((end_time - start_time) / 60) - (hours * 60)
    seconds = int((end_time - start_time) % 60)
    return hours, minutes, seconds

#feature extraction slow fast inference
@torch.no_grad()
def perform_inference(inputs, model, cfg):
    """
    Perform mutli-view testing that samples a segment of frames from a video
    and extract features from a pre-trained model.
    Args:
        test_loader (loader): video testing loader.
        model (model): the pretrained video model to test.
        cfg (CfgNode): configs. Details can be found in
            slowfast/config/defaults.py
    """
    # Enable eval mode.
    model.eval()

    feat_arr = None

    # Transfer the data to the current GPU device.
    if isinstance(inputs, (list,)):
        for i in range(len(inputs)):
            inputs[i] = inputs[i].cuda(device=cfg.USED_GPU,non_blocking=True)
    else:
        inputs = inputs.cuda(device=cfg.USED_GPU,non_blocking=True)

    # Perform the forward pass.
    preds, feat = model(inputs)
    # Gather all the predictions across all the devices to perform ensemble.
    if cfg.NUM_GPUS > 1:
        preds, feat = du.all_gather([preds, feat])

    feat = feat.cpu().numpy()

    if feat_arr is None:
        feat_arr = feat
    else:
        feat_arr = np.concatenate((feat_arr, feat), axis=0)

    return feat_arr

# %%
#video feature extraction stream output
def test(model,cfg,inputs):
    """
    Perform multi-view testing/feature extraction on the pretrained video model.
    Args:
        cfg (CfgNode): configs. Details can be found in
            slowfast/config/defaults.py
    """

    # Set random seed from configs.
    np.random.seed(cfg.RNG_SEED)
    torch.manual_seed(cfg.RNG_SEED)

    # Setup logging format.
    logging.setup_logging(cfg.OUTPUT_DIR)

    # Print config.
    #logger.info("Test with config:")
    #logger.info(cfg)

    # Build the video model and print model statistics.
    
    #if du.is_master_proc() and cfg.LOG_MODEL_INFO:
        #misc.log_model_info(model, cfg, use_train_input=False)

    #changes here
    #checkpoint = torch.load("/data/disk/LUO/slowfast/feature_extract/checkpoints/checkpoint_epoch_00130.pyth")
    #model.load_state_dict(checkpoint['model_state'])

    #cu.load_test_checkpoint(cfg, model)


    start_time = time.time()


    # Perform multi-view test on the entire dataset.
    feat_arr = perform_inference(inputs, model, cfg)
    return feat_arr

# %%
# tridet evaluation configs

# %%
# python imports
import argparse
import os
import glob
import time
from pprint import pprint

# torch imports
import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
import torch.utils.data

# our code
from libs.core import load_tridet_config
from libs.datasets import make_dataset, make_data_loader
from libs.modeling import make_meta_arch
from libs.utils import valid_one_epoch, ANETdetection, fix_random_seed

# %%
#create test dataset
import os
import json
import h5py
import numpy as np
import pandas as pd

import torch
from torch.utils.data import Dataset
from torch.nn import functional as F

from libs.datasets.datasets import register_dataset
from libs.datasets.data_utils import truncate_feats
from libs.utils import remove_duplicate_annotations

# %%
def _load_json(label_dict=None,split=['testing'],num_classes=19,json_file="/data/disk/LUO/test_only/r_tridet/TriDet/data/cataract/data_1102.json",default_fps=30):

        #create a csv
        #frame_start,frame_end,label,training_or_testing
        # load database and select the subset
        with open(json_file) as f:
            json_data = json.load(f)
        # if label_dict is not available, matching label(str) to label id (int)
        if label_dict is None:
            label_dict = {
            #define surgical phase name to phase label id
                "phase_{}".format(i+1):i for i in range(num_classes)
            }
            
        if split[0] == "training":
            split_name = "train"
        else:
            split_name = "test"
        # fill in the db (immutable afterwards)
        dict_db = tuple()
        for key, value in json_data.items():
            # key is the video id, v is the segement information
            # get fps if available

            if split_name not in value["annotation"][0]["subset"]:
                continue
            if default_fps is not None:
                fps = default_fps
            else:
                #fps=30
                fps = 1

            duration = []
            num_phase = len(value["annotation"])
            segments = np.zeros([num_phase, 2], dtype=np.float32)
            labels = np.zeros([num_phase, ], dtype=np.int64)
            for idx,phase in enumerate(value["annotation"]):
                duration.append(phase["time_till_now"])
                segments[idx][0] = phase["start"]
                segments[idx][1] = phase["end"]
                if num_classes == 1:
                    labels[idx] = 0
                else:
                    labels[idx] = phase["label"]
            last_time = value["last_time"]
            dict_db += ({'id': key.split(".")[0],
                         'fps': fps,
                         'duration': last_time,
                         'segments': segments,
                         'labels': labels
                         },)

        return dict_db, label_dict

# %%
def getitem(data_list,features, idx,num_frames,max_seq_len=1024,feat_stride=1,downsample_rate=1,force_upsampling=False,mirror=True):
    # directly return a (truncated) data point (so it is very fast!)
    # auto batching will be disabled in the subsequent dataloader
    # instead the model will need to decide how to batch / preporcess the data
    video_item = data_list[idx]

    # load features
    feats = features

    #shape is T x 2304
    # we support both fixed length features / variable length features
    if feat_stride > 0 and (not force_upsampling):
        # var length features
        feat_stride, num_frames = feat_stride, num_frames
        # only apply down sampling here
        if downsample_rate > 1:
            feats = feats[::downsample_rate, :]
            feat_stride = feat_stride * downsample_rate

    # T x C -> C x T
    if isinstance(feats, torch.Tensor):
        feats = feats.transpose(0, 1)
    else:
        feats = torch.from_numpy(np.ascontiguousarray(feats.transpose()))

    # convert time stamp (in second) into temporal feature grids
    # ok to have small negative values here
    if video_item['segments'] is not None:
        segments = torch.from_numpy(
            #(video_item['segments'] * video_item['fps'] - 0.5 * num_frames) / (feat_stride)
            video_item['segments']
        )
        labels = torch.from_numpy(video_item['labels'])
        # for activity net, we have a few videos with a bunch of missing frames
        # here is a quick fix for training
        segments, labels = None, None

    # return a data dict
    data_dict = {'video_id': video_item['id'],
                    'feats': feats,  # C x T
                    'segments': segments,  # N x 2
                    'labels': labels,  # N
                    'fps': 1,
                    'duration': num_frames,
                    'feat_stride': feat_stride,
                    'feat_num_frames': 32}


    return data_dict

# %%
class AverageMeter(object):
    """Computes and stores the average and current value.
    Used to compute dataset stats from mini-batches
    """

    def __init__(self):
        self.initialized = False
        self.val = None
        self.avg = None
        self.sum = None
        self.count = 0.0

    def initialize(self, val, n):
        self.val = val
        self.avg = val
        self.sum = val * n
        self.count = n
        self.initialized = True

    def update(self, val, n=1):
        if not self.initialized:
            self.initialize(val, n)
        else:
            self.add(val, n)

    def add(self, val, n):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
def valid_one_epoch(
        dict_db,
        model,
        curr_epoch=0,
        ext_score_file=None,
        evaluator=None,
        output_file=None,
        tb_writer=None,
        print_freq=20
):
    """Test the model on the validation set"""
    # either evaluate the results or save the results

    # set up meters
    batch_time = AverageMeter()
    # switch to evaluate mode
    model.eval()
    # dict for results (for our evaluation code)
    results = {
        'video-id': [],
        't-start': [],
        't-end': [],
        'label': [],
        'score': []
    }

    # loop over validation set
    start = time.time()
        # forward the model (wo. grad)
    with torch.no_grad():
        output = model(dict_db)

        # upack the results into ANet format
        num_vids = len(output)
        for vid_idx in range(num_vids):
            if output[vid_idx]['segments'].shape[0] > 0:
                results['video-id'].extend(
                    [output[vid_idx]['video_id']] *
                    output[vid_idx]['segments'].shape[0]
                )
                results['t-start'].append(output[vid_idx]['segments'][:, 0])
                results['t-end'].append(output[vid_idx]['segments'][:, 1])
                results['label'].append(output[vid_idx]['labels'])
                results['score'].append(output[vid_idx]['scores'])


    # gather all stats and evaluate
    results['t-start'] = torch.cat(results['t-start']).numpy()
    results['t-end'] = torch.cat(results['t-end']).numpy()
    results['label'] = torch.cat(results['label']).numpy()
    results['score'] = torch.cat(results['score']).numpy()

    return results

# %%
import os
import json
import pandas as pd
import numpy as np
from joblib import Parallel, delayed
from typing import List
from typing import Tuple
from typing import Dict
import datetime

# %%
def load_gt_seg_from_json(json_file, split=None, label='label', label_offset=0):
    # load json file
    with open(json_file, "r", encoding="utf8") as f:
        json_db = json.load(f)

    vids, starts, stops, labels = [], [], [], []
    if split == "training":
        split_name = "train"
    else:
        split_name = "test"
    for k, v in json_db.items():

        for segments in v["annotation"]:
            if split_name not in segments["subset"]:
                continue
            ants = segments
            vids.append(k.split(".")[0])
            starts.append(ants["start"])
            stops.append(ants["end"])
            labels.append(ants["label"])



        """# filter based on split
        if split_name not in k:
            continue
        # remove duplicated instances
        ants = v
        # video id
        vids += [k] * len(ants)
        # for each event, grab the start/end time and label
        for event in ants:
            starts += [float(event['start'])]
            stops += [float(event['end'])]
            if isinstance(event[label], (Tuple, List)):
                # offset the labels by label_offset
                label_id = 0
                for i, x in enumerate(event[label][::-1]):
                    label_id += label_offset ** i + int(x)
            else:
                # load label_id directly
                label_id = int(event[label])
            labels += [label_id]"""

    # move to pd dataframe
    gt_base = pd.DataFrame({
        'video-id': vids,
        't-start': starts,
        't-end': stops,
        'label': labels
    })

    return gt_base

# %%
def to_df(preds):
        """Evaluates a prediction file. For the detection task we measure the
        interpolated mean average precision to measure the performance of a
        method.
        preds can be (1) a pd.DataFrame; or (2) a json file where the data will be loaded;
        or (3) a python dict item with numpy arrays as the values
        """

        if isinstance(preds, Dict):
            # move to pd dataframe
            # did not check dtype here, can accept both numpy / pytorch tensors
            preds = pd.DataFrame({
                'video-id': preds['video-id'],
                't-start': preds['t-start'].tolist(),
                't-end': preds['t-end'].tolist(),
                'label': preds['label'].tolist(),
                'score': preds['score'].tolist()
            })



        return preds

# %%
def calculate_acc(pred_df,gt_df):
    with open("/data/disk/LUO/test_only/r_tridet/TriDet/data/cataract/data_1102.json","r") as f:
        gt_json = json.load(f)
    df_gt= pd.DataFrame(columns=["video_id","gt_labels"])
    for k,v in gt_json.items():
        if "train" in k:
            continue
        dur = v["last_time"]
        video_name = k.split(".")[0]
        gt_labels = [0 for i in range(int(np.round(dur)))]
        video_id = [k for i in range(int(np.round(dur)))]
        df = pd.DataFrame(columns=["video_id","gt_labels"])
        df["video_id"] = video_id
        df["gt_labels"] = gt_labels
        subset = gt_df[gt_df["video-id"]==video_name]
        
        for index in subset.index:
            start = int(np.round(subset.loc[index]["t-start"]))
            end = int(np.round(subset.loc[index]["t-end"]))
            label = subset.loc[index]["label"]
            for i in range(start,end+1):
                df.loc[i,"gt_labels"] = label+1
        
        df_gt = pd.concat([df_gt,df],ignore_index=True)    
    df_pred = pd.DataFrame(columns=["video_id","pred_labels"])


    for k,v in gt_json.items():
        if "train" in k:
            continue
        video_name = k.split(".")[0]
        dur = v["last_time"]
        gt_labels = [0 for i in range(int(np.round(dur)))]
        video_id = [k for i in range(int(np.round(dur)))]
        df = pd.DataFrame(columns=["video_id","pred_labels"])
        df["video_id"] = video_id
        df["pred_labels"] = gt_labels
        subset = pred_df[pred_df["video-id"]==video_name]
        
        for index in subset.index:
            start = int(np.round(subset.loc[index]["t-start"]))
            end = int(np.round(subset.loc[index]["t-end"]))
            label = subset.loc[index]["label"]
            for i in range(start,end+1):
                if i>=len(df):
                    continue
                df.loc[i,"pred_labels"] = label+1
        #print(df)
        df_pred = pd.concat([df_pred,df],ignore_index=True)


    return df_pred
    """
    df_all =pd.concat([df_gt,df_pred["pred_labels"]],axis=1)
    acc = accuracy_score(df_all["gt_labels"].to_list(),df_all["pred_labels"].to_list())
    f1 = f1_score(df_all["gt_labels"].to_list(),df_all["pred_labels"].to_list(),average="macro")
    recall = recall_score(df_all["gt_labels"].to_list(),df_all["pred_labels"].to_list(),average="macro")
    precision = precision_score(df_all["gt_labels"].to_list(),df_all["pred_labels"].to_list(),average="macro")
    df_pred.to_csv("df_pred.csv",index=False)
    df_gt.to_csv("df_gt.csv",index=False)
    print("accuracy under the threshold : ", acc,end="     ")
    print("f1 score under the threshold : ", f1,end="     ")
    print("precision score under the threshold : ", precision,end="     ")
    print("recall score under the threshold : ", recall)
    """

# %%
def get_middle_label(pred_df,mid_index,threshold=0.22):
    df = pred_df[pred_df["score"]>threshold]
    label = 0
    score = threshold
    s = mid_index[0]
    e = mid_index[1]
    #filter df
    if len(df) == 0:
        for i in range(len(pred_df)):
            if pred_df.iloc[i]["t-start"]<=e and pred_df.iloc[i]["t-end"]>=s:
                label = 0
                score = pred_df.iloc[i]["score"]
                break
    for i in range(len(df)):
        if df.iloc[i]["t-start"]<=e and df.iloc[i]["t-end"]>=s:
            label = df.iloc[i]["label"]
            score = df.iloc[i]["score"]
            break
    return label,score

# %%
"""def get_middle_label(pred_df,mid_index,threshold=0.22):
    df = pred_df[pred_df["score"]>threshold]
    label = 0
    s = mid_index[0]
    e = mid_index[1]
    #filter df
    for i in range(len(df)):
        if mid_index>=df.iloc[i]["t-start"] and mid_index <= df.iloc[i]["t-end"]:
            label = df.iloc[i]["label"]
            break
    return label"""
# Out:
# 'def get_middle_label(pred_df,mid_index,threshold=0.22):\n    df = pred_df[pred_df["score"]>threshold]\n    label = 0\n    s = mid_index[0]\n    e = mid_index[1]\n    #filter df\n    for i in range(len(df)):\n        if mid_index>=df.iloc[i]["t-start"] and mid_index <= df.iloc[i]["t-end"]:\n            label = df.iloc[i]["label"]\n            break\n    return label'

# %%
def mirror_feature(inputs,fill_n_times=3):
    #return the mirrored inputs, e.g (2304,100) -> (2304,200)
    feat = inputs["feats"]
    feat_flipped = torch.flip(feat, dims=[1])
    if fill_n_times>0:
        feat_fill = feat[:,-1].unsqueeze(-1).repeat(1,fill_n_times)
        feat_mirrored = torch.concat((feat, feat_fill,feat_flipped), dim=1)
        if feat_mirrored.size(1)>1024:
            center = feat_mirrored.size(1)//2
            start_index = center-512
            end_index = center+512
            feat_mirrored = feat_mirrored[:, start_index:end_index]
            inputs["feats"] = feat_mirrored
            inputs['duration'] = 1024
            return inputs
        inputs["feats"] = feat_mirrored
        inputs['duration'] = inputs['duration']*2+fill_n_times
    else:
        feat_mirrored = torch.concat((feat, feat_fill,feat_flipped), dim=1)
        inputs["feats"] = feat_mirrored
        inputs['duration'] = inputs['duration']*2
    return inputs

# %%
def fill_feature(inputs,fill_n_times=3):
        #return the mirrored inputs, e.g (2304,100) -> (2304,200)
    input_copy = copy.deepcopy(inputs)
    feat = input_copy["feats"]
    if fill_n_times>0:
        feat_fill = feat[:,-1].unsqueeze(-1).repeat(1,fill_n_times)
        feat_filled = torch.concat((feat, feat_fill), dim=1)
        if feat_filled.size(1)>1024:
            center = feat_filled.size(1)//2
            start_index = center-512
            end_index = center+512
            feat_filled = feat_filled[:, start_index:end_index]
            input_copy["feats"] = feat_filled
            input_copy['duration'] = 1024
            return input_copy
        input_copy["feats"] = feat_filled
        input_copy['duration'] = input_copy['duration']+fill_n_times
    return input_copy

# %%
def smooth(length=10,)

# %%
#Feature extraction configs
args = parse_args()
cfg = load_config(args)
cfg.USED_GPU = 7 #make sure it is same as device
vid_path = "/data/disk/cataracts_dataset/test_video/test01.mp4"

#tridet_cfg = load_tridet_config("/data/disk/LUO/test_only/TriDet/configs/cataract_slowfast.yaml")

#ckpt_file = '/data/disk/LUO/epoch_110_best.pth.tar'

tridet_cfg = load_tridet_config("/data/disk/LUO/test_only/TriDet/configs/cataract_slowfast_reverse.yaml")
ckpt_file = '/data/disk/LUO/test_only/TriDet/ckpt/cataract_slowfast_reverse_reverse/epoch_100.pth.tar'

topk=-1
print_freq = 10
save_only = False

# fix the random seeds (this will fix everything)
_ = fix_random_seed(0, include_cuda=True)

# %%
device = "cuda:7"
cap = cv2.VideoCapture(vid_path)
sample_height = 256
sample_width = 256
count = 0
seq_length = 32
queue = deque(maxlen=32)
ret = True
frame_wise_feature = None
extract_model = build_model(cfg).to(device)
print("loading feature extraction model")
extract_checkpoint = torch.load("/data/disk/LUO/slowfast/feature_extract/checkpoints/checkpoint_epoch_00130.pyth",map_location=device)
extract_model.load_state_dict(extract_checkpoint['model_state'])
del extract_checkpoint
idx = int(vid_path.split("/")[-1].split(".")[0].split("test")[-1])-1 #test01 -> 0
dict_db,label_dict = _load_json() #dict_db contains segments and labels
current_db = dict_db[idx] #current test file json
count_2 = 0 #count after queue is full
num_fill = 24
# load tridet model
model = make_meta_arch(tridet_cfg['model_name'], **tridet_cfg['model'])
# not ideal for multi GPU training, ok for now
model = nn.DataParallel(model, device_ids=tridet_cfg['devices'])
print("=> loading checkpoint '{}'".format(ckpt_file))
# load ckpt, reset epoch / best rmse
checkpoint = torch.load(
    ckpt_file,
    map_location=lambda storage, loc: storage.cuda(tridet_cfg['devices'][0])
)

# load ema model instead
print("Loading from EMA model ...")
model.load_state_dict(checkpoint['state_dict_ema'])
del checkpoint
pure_pred_list = []
fill_pred_list = []
pred_list = []
start = datetime.datetime.now()
while ret:
    #print("count: ",count)
    
    ret,frame = cap.read()
    if not ret:
        print("finished")
        break
    height, width = frame.shape[:2]
    frame = cv2.resize(frame,(sample_height,sample_width),interpolation = cv2.INTER_LINEAR)
    queue.append(frame)
    if count<32:
        count+=1
        continue
    else:
        
        frames = np.stack(queue, axis=0)
        frames = pre_process_frame(frames)
        frame_list = pack_pathway_output(cfg, frames) #得到一个list,list[0]为(3,8,256,256),[1]为[3,32,256,256]分别表示slow和fast两条线
        frame_list[0] = frame_list[0].unsqueeze(0) #增加一个batch维度
        frame_list[1] = frame_list[1].unsqueeze(0)
        if count_2%30 == 0: #每30表示的是每30个frame，即每一秒取一次feature
            cur_second = count//30
            print("current second: ",cur_second)
            if frame_wise_feature is None:
                frame_wise_feature = test(extract_model,cfg,frame_list) #得到每32个frame为单位的一个feature，size大小为(1,2304)
                #print("frame_wise_feture",frame_wise_feture.shape)
                #print(test(cfg,frame_list))
            else:
                #print("frame_wise_feture ",frame_wise_feture.shape)
                cur_feature = test(extract_model,cfg,frame_list)
                #print("cur_feature ",cur_feature.shape)
                frame_wise_feature = np.concatenate((frame_wise_feature,cur_feature),axis=0)
                #print(frame_wise_feture.shape)
                #将frame_wise_feature 在dim 0 上concate起来，放入surgplan的eval方程
            
            
            #transfer input frame_wise_features into dictionary
            inputs = getitem(data_list=dict_db,features=frame_wise_feature, idx=idx,num_frames=len(frame_wise_feature))
            results = valid_one_epoch([inputs],model=model)
            df = to_df(results)
            pred_label,score = get_middle_label(df,[cur_second-2,cur_second],threshold=0.22)
            pure_pred_list.append(pred_label)
            print("no mirror predicted label: ",pred_label," score:",score)
            #ret = False
            #inference

            filled_feature = fill_feature(inputs,num_fill)
            results = valid_one_epoch([filled_feature],model=model)
            df = to_df(results)
            pred_label,score = get_middle_label(df,[cur_second-2,cur_second+num_fill],threshold=0.22)
            fill_pred_list.append(pred_label)
            print("filled predicted label: ",pred_label," score:",score)

            mirror_features = mirror_feature(inputs,num_fill)
            results = valid_one_epoch([mirror_features],model=model)
            df = to_df(results)
            if cur_second == 400:
                print("400")
            if inputs["feats"].size(1) >= 1024:
                pred_label,score = get_middle_label(df,[512-num_fill//2,512+num_fill//2],0.22)
            else:
                pred_label,score = get_middle_label(df,[cur_second+num_fill-2,cur_second+num_fill],threshold=0.22)

            print("mirror predicted label: ",pred_label," score:",score)
            print()
            pred_list.append(pred_label)
        count+=1
        count_2 +=1 
end = datetime.datetime.now()

print("total time: ", (end-start).seconds)
# Out:
# loading feature extraction model
# => loading checkpoint '/data/disk/LUO/test_only/TriDet/ckpt/cataract_slowfast_reverse_reverse/epoch_100.pth.tar'
# Loading from EMA model ...
# current second:  1
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  2
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  3
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  4
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  5
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  6
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  7
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  8
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  9
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  10
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  11
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  12
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  13
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  14
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  15
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  16
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  5  score: 0.4673518240451813
# mirror predicted label:  5  score: 0.5317040681838989
#
# current second:  17
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  18
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  5  score: 0.7338364124298096
# mirror predicted label:  5  score: 0.7376885414123535
#
# current second:  19
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  5  score: 0.6518883109092712
# mirror predicted label:  5  score: 0.7839241027832031
#
# current second:  20
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  21
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  22
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  23
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  24
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  25
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  26
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  27
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  28
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  3  score: 0.4925185739994049
# mirror predicted label:  3  score: 0.5363487005233765
#
# current second:  29
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  3  score: 0.5405871272087097
# mirror predicted label:  3  score: 0.5640999674797058
#
# current second:  30
# no mirror predicted label:  3  score: 0.23463398218154907
# filled predicted label:  3  score: 0.4018304646015167
# mirror predicted label:  3  score: 0.40027284622192383
#
# current second:  31
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  3  score: 0.27409273386001587
# mirror predicted label:  3  score: 0.2675939202308655
#
# current second:  32
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  33
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  34
# no mirror predicted label:  3  score: 0.3479214012622833
# filled predicted label:  3  score: 0.508159875869751
# mirror predicted label:  3  score: 0.5669388175010681
#
# current second:  35
# no mirror predicted label:  3  score: 0.444123774766922
# filled predicted label:  3  score: 0.6411093473434448
# mirror predicted label:  3  score: 0.7096201777458191
#
# current second:  36
# no mirror predicted label:  3  score: 0.3962191641330719
# filled predicted label:  3  score: 0.790536105632782
# mirror predicted label:  3  score: 0.831622838973999
#
# current second:  37
# no mirror predicted label:  3  score: 0.47716474533081055
# filled predicted label:  3  score: 0.556024432182312
# mirror predicted label:  3  score: 0.5590133666992188
#
# current second:  38
# no mirror predicted label:  3  score: 0.5057861804962158
# filled predicted label:  3  score: 0.6675875186920166
# mirror predicted label:  3  score: 0.6700666546821594
#
# current second:  39
# no mirror predicted label:  3  score: 0.4897104501724243
# filled predicted label:  3  score: 0.3568693995475769
# mirror predicted label:  3  score: 0.4480460286140442
#
# current second:  40
# no mirror predicted label:  3  score: 0.5075053572654724
# filled predicted label:  3  score: 0.363590270280838
# mirror predicted label:  3  score: 0.40941351652145386
#
# current second:  41
# no mirror predicted label:  3  score: 0.413531631231308
# filled predicted label:  3  score: 0.36532464623451233
# mirror predicted label:  3  score: 0.34403201937675476
#
# current second:  42
# no mirror predicted label:  3  score: 0.42510268092155457
# filled predicted label:  3  score: 0.38536518812179565
# mirror predicted label:  3  score: 0.4292258620262146
#
# current second:  43
# no mirror predicted label:  3  score: 0.4701768755912781
# filled predicted label:  3  score: 0.6237806081771851
# mirror predicted label:  3  score: 0.67015141248703
#
# current second:  44
# no mirror predicted label:  3  score: 0.46267426013946533
# filled predicted label:  3  score: 0.3646259605884552
# mirror predicted label:  0  score: 0.22
#
# current second:  45
# no mirror predicted label:  3  score: 0.42634689807891846
# filled predicted label:  3  score: 0.7913678884506226
# mirror predicted label:  3  score: 0.796299397945404
#
# current second:  46
# no mirror predicted label:  3  score: 0.6757597327232361
# filled predicted label:  3  score: 0.7780036330223083
# mirror predicted label:  3  score: 0.8234346508979797
#
# current second:  47
# no mirror predicted label:  3  score: 0.6662771701812744
# filled predicted label:  3  score: 0.7834044694900513
# mirror predicted label:  3  score: 0.8314407467842102
#
# current second:  48
# no mirror predicted label:  3  score: 0.6641437411308289
# filled predicted label:  3  score: 0.6799920797348022
# mirror predicted label:  3  score: 0.7583862543106079
#
# current second:  49
# no mirror predicted label:  3  score: 0.6976941227912903
# filled predicted label:  3  score: 0.6812107563018799
# mirror predicted label:  0  score: 0.22
#
# current second:  50
# no mirror predicted label:  3  score: 0.6702319383621216
# filled predicted label:  4  score: 0.9016139507293701
# mirror predicted label:  4  score: 0.9189366698265076
#
# current second:  51
# no mirror predicted label:  4  score: 0.8991308808326721
# filled predicted label:  4  score: 0.882301926612854
# mirror predicted label:  4  score: 0.9043104648590088
#
# current second:  52
# no mirror predicted label:  4  score: 0.9839895367622375
# filled predicted label:  4  score: 0.8947413563728333
# mirror predicted label:  4  score: 0.5033140778541565
#
# current second:  53
# no mirror predicted label:  4  score: 0.9736413955688477
# filled predicted label:  4  score: 0.9953106045722961
# mirror predicted label:  0  score: 0.22
#
# current second:  54
# no mirror predicted label:  4  score: 0.9904404878616333
# filled predicted label:  4  score: 0.9946263432502747
# mirror predicted label:  0  score: 0.22
#
# current second:  55
# no mirror predicted label:  4  score: 0.994217038154602
# filled predicted label:  4  score: 0.9945064187049866
# mirror predicted label:  0  score: 0.22
#
# current second:  56
# no mirror predicted label:  4  score: 0.99442058801651
# filled predicted label:  4  score: 0.9943894743919373
# mirror predicted label:  0  score: 0.22
#
# current second:  57
# no mirror predicted label:  4  score: 0.9944396018981934
# filled predicted label:  4  score: 0.9943704009056091
# mirror predicted label:  0  score: 0.22
#
# current second:  58
# no mirror predicted label:  4  score: 0.9944447875022888
# filled predicted label:  4  score: 0.9941830039024353
# mirror predicted label:  0  score: 0.22
#
# current second:  59
# no mirror predicted label:  4  score: 0.9944485425949097
# filled predicted label:  4  score: 0.9942436814308167
# mirror predicted label:  0  score: 0.22
#
# current second:  60
# no mirror predicted label:  4  score: 0.994453489780426
# filled predicted label:  4  score: 0.9942454695701599
# mirror predicted label:  0  score: 0.22
#
# current second:  61
# no mirror predicted label:  4  score: 0.9944548010826111
# filled predicted label:  4  score: 0.9942400455474854
# mirror predicted label:  0  score: 0.22
#
# current second:  62
# no mirror predicted label:  4  score: 0.9944556355476379
# filled predicted label:  4  score: 0.9941843152046204
# mirror predicted label:  0  score: 0.22
#
# current second:  63
# no mirror predicted label:  4  score: 0.9944542050361633
# filled predicted label:  4  score: 0.9941564798355103
# mirror predicted label:  0  score: 0.22
#
# current second:  64
# no mirror predicted label:  4  score: 0.9944544434547424
# filled predicted label:  4  score: 0.994159460067749
# mirror predicted label:  5  score: 0.22909659147262573
#
# current second:  65
# no mirror predicted label:  4  score: 0.9944524168968201
# filled predicted label:  4  score: 0.994097113609314
# mirror predicted label:  5  score: 0.5052021145820618
#
# current second:  66
# no mirror predicted label:  4  score: 0.994452178478241
# filled predicted label:  4  score: 0.9941393136978149
# mirror predicted label:  5  score: 0.5601096749305725
#
# current second:  67
# no mirror predicted label:  4  score: 0.9944562911987305
# filled predicted label:  4  score: 0.994156002998352
# mirror predicted label:  5  score: 0.5978902578353882
#
# current second:  68
# no mirror predicted label:  4  score: 0.9944551587104797
# filled predicted label:  4  score: 0.9941027760505676
# mirror predicted label:  5  score: 0.6239473223686218
#
# current second:  69
# no mirror predicted label:  4  score: 0.9944508075714111
# filled predicted label:  4  score: 0.994085431098938
# mirror predicted label:  5  score: 0.40602028369903564
#
# current second:  70
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  5  score: 0.5928152799606323
# mirror predicted label:  5  score: 0.671317458152771
#
# current second:  71
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  5  score: 0.5608943700790405
# mirror predicted label:  5  score: 0.747001588344574
#
# current second:  72
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  5  score: 0.47652721405029297
# mirror predicted label:  5  score: 0.6234817504882812
#
# current second:  73
# no mirror predicted label:  5  score: 0.31827622652053833
# filled predicted label:  5  score: 0.6142754554748535
# mirror predicted label:  5  score: 0.745182454586029
#
# current second:  74
# no mirror predicted label:  5  score: 0.37403231859207153
# filled predicted label:  5  score: 0.6597208976745605
# mirror predicted label:  5  score: 0.6883748173713684
#
# current second:  75
# no mirror predicted label:  5  score: 0.41942185163497925
# filled predicted label:  5  score: 0.8668817281723022
# mirror predicted label:  5  score: 0.9153250455856323
#
# current second:  76
# no mirror predicted label:  5  score: 0.4359811246395111
# filled predicted label:  5  score: 0.8679095506668091
# mirror predicted label:  5  score: 0.7949896454811096
#
# current second:  77
# no mirror predicted label:  5  score: 0.4699788987636566
# filled predicted label:  5  score: 0.9110660552978516
# mirror predicted label:  5  score: 0.8924698829650879
#
# current second:  78
# no mirror predicted label:  5  score: 0.47978490591049194
# filled predicted label:  5  score: 0.7843915820121765
# mirror predicted label:  5  score: 0.6740592122077942
#
# current second:  79
# no mirror predicted label:  5  score: 0.46656540036201477
# filled predicted label:  5  score: 0.6694710850715637
# mirror predicted label:  5  score: 0.7183502912521362
#
# current second:  80
# no mirror predicted label:  5  score: 0.46552613377571106
# filled predicted label:  5  score: 0.8981174230575562
# mirror predicted label:  5  score: 0.8344824910163879
#
# current second:  81
# no mirror predicted label:  5  score: 0.5305987596511841
# filled predicted label:  5  score: 0.6954045295715332
# mirror predicted label:  5  score: 0.783303439617157
#
# current second:  82
# no mirror predicted label:  5  score: 0.5747993588447571
# filled predicted label:  5  score: 0.6910308599472046
# mirror predicted label:  5  score: 0.7613487243652344
#
# current second:  83
# no mirror predicted label:  5  score: 0.5519490838050842
# filled predicted label:  5  score: 0.913386344909668
# mirror predicted label:  5  score: 0.9000839591026306
#
# current second:  84
# no mirror predicted label:  5  score: 0.5937813520431519
# filled predicted label:  5  score: 0.7611269354820251
# mirror predicted label:  5  score: 0.7170182466506958
#
# current second:  85
# no mirror predicted label:  5  score: 0.6562281250953674
# filled predicted label:  5  score: 0.8092221617698669
# mirror predicted label:  5  score: 0.6807262897491455
#
# current second:  86
# no mirror predicted label:  5  score: 0.6554860472679138
# filled predicted label:  5  score: 0.6733306646347046
# mirror predicted label:  5  score: 0.7508633732795715
#
# current second:  87
# no mirror predicted label:  5  score: 0.637206494808197
# filled predicted label:  5  score: 0.6826935410499573
# mirror predicted label:  5  score: 0.7767841219902039
#
# current second:  88
# no mirror predicted label:  5  score: 0.6502928137779236
# filled predicted label:  5  score: 0.6855694651603699
# mirror predicted label:  5  score: 0.7593107223510742
#
# current second:  89
# no mirror predicted label:  5  score: 0.7169949412345886
# filled predicted label:  5  score: 0.8270841836929321
# mirror predicted label:  5  score: 0.7284868359565735
#
# current second:  90
# no mirror predicted label:  5  score: 0.7254126667976379
# filled predicted label:  5  score: 0.8647836446762085
# mirror predicted label:  5  score: 0.7285383343696594
#
# current second:  91
# no mirror predicted label:  5  score: 0.7131473422050476
# filled predicted label:  5  score: 0.6962610483169556
# mirror predicted label:  5  score: 0.6235596537590027
#
# current second:  92
# no mirror predicted label:  5  score: 0.7060226798057556
# filled predicted label:  5  score: 0.7165965437889099
# mirror predicted label:  5  score: 0.7746416926383972
#
# current second:  93
# no mirror predicted label:  5  score: 0.7204910516738892
# filled predicted label:  5  score: 0.7866103649139404
# mirror predicted label:  5  score: 0.7766745090484619
#
# current second:  94
# no mirror predicted label:  5  score: 0.7250640392303467
# filled predicted label:  5  score: 0.7122572660446167
# mirror predicted label:  5  score: 0.6548112034797668
#
# current second:  95
# no mirror predicted label:  5  score: 0.7175631523132324
# filled predicted label:  5  score: 0.7083654999732971
# mirror predicted label:  5  score: 0.3546714782714844
#
# current second:  96
# no mirror predicted label:  5  score: 0.7168278098106384
# filled predicted label:  5  score: 0.7080574631690979
# mirror predicted label:  5  score: 0.7382851243019104
#
# current second:  97
# no mirror predicted label:  5  score: 0.7296984791755676
# filled predicted label:  5  score: 0.7009798884391785
# mirror predicted label:  5  score: 0.8284425735473633
#
# current second:  98
# no mirror predicted label:  5  score: 0.7275145053863525
# filled predicted label:  5  score: 0.7623704075813293
# mirror predicted label:  5  score: 0.8714249134063721
#
# current second:  99
# no mirror predicted label:  5  score: 0.7259050011634827
# filled predicted label:  5  score: 0.691730260848999
# mirror predicted label:  5  score: 0.8623598217964172
#
# current second:  100
# no mirror predicted label:  5  score: 0.7252079844474792
# filled predicted label:  5  score: 0.7085051536560059
# mirror predicted label:  5  score: 0.6669268608093262
#
# current second:  101
# no mirror predicted label:  5  score: 0.7241091132164001
# filled predicted label:  5  score: 0.7097988724708557
# mirror predicted label:  5  score: 0.3920297622680664
#
# current second:  102
# no mirror predicted label:  5  score: 0.723488450050354
# filled predicted label:  5  score: 0.7112459540367126
# mirror predicted label:  5  score: 0.3738490343093872
#
# current second:  103
# no mirror predicted label:  5  score: 0.7230812907218933
# filled predicted label:  5  score: 0.6898686289787292
# mirror predicted label:  5  score: 0.7453904747962952
#
# current second:  104
# no mirror predicted label:  5  score: 0.7224318385124207
# filled predicted label:  5  score: 0.69626384973526
# mirror predicted label:  5  score: 0.7413021326065063
#
# current second:  105
# no mirror predicted label:  5  score: 0.7188921570777893
# filled predicted label:  5  score: 0.6755845546722412
# mirror predicted label:  5  score: 0.7639182209968567
#
# current second:  106
# no mirror predicted label:  5  score: 0.7175320386886597
# filled predicted label:  5  score: 0.742522656917572
# mirror predicted label:  5  score: 0.7613682150840759
#
# current second:  107
# no mirror predicted label:  5  score: 0.7169064283370972
# filled predicted label:  5  score: 0.7036727666854858
# mirror predicted label:  5  score: 0.7426130771636963
#
# current second:  108
# no mirror predicted label:  5  score: 0.7162666916847229
# filled predicted label:  5  score: 0.6950554251670837
# mirror predicted label:  5  score: 0.8148320317268372
#
# current second:  109
# no mirror predicted label:  5  score: 0.7137544751167297
# filled predicted label:  5  score: 0.7530716061592102
# mirror predicted label:  5  score: 0.828886091709137
#
# current second:  110
# no mirror predicted label:  5  score: 0.7131643295288086
# filled predicted label:  5  score: 0.698784589767456
# mirror predicted label:  5  score: 0.6701450943946838
#
# current second:  111
# no mirror predicted label:  5  score: 0.7120969891548157
# filled predicted label:  5  score: 0.6831481456756592
# mirror predicted label:  5  score: 0.7963347434997559
#
# current second:  112
# no mirror predicted label:  5  score: 0.7108843326568604
# filled predicted label:  5  score: 0.668922483921051
# mirror predicted label:  5  score: 0.7513251900672913
#
# current second:  113
# no mirror predicted label:  5  score: 0.7078772187232971
# filled predicted label:  5  score: 0.6748037934303284
# mirror predicted label:  5  score: 0.7103755474090576
#
# current second:  114
# no mirror predicted label:  5  score: 0.7066643238067627
# filled predicted label:  5  score: 0.668325662612915
# mirror predicted label:  5  score: 0.7092658281326294
#
# current second:  115
# no mirror predicted label:  5  score: 0.7055862545967102
# filled predicted label:  6  score: 0.6933739185333252
# mirror predicted label:  5  score: 0.7492756247520447
#
# current second:  116
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  5  score: 0.6805871725082397
# mirror predicted label:  5  score: 0.6631877422332764
#
# current second:  117
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  5  score: 0.687436580657959
# mirror predicted label:  5  score: 0.6742650866508484
#
# current second:  118
# no mirror predicted label:  6  score: 0.27271607518196106
# filled predicted label:  6  score: 0.523891806602478
# mirror predicted label:  5  score: 0.6405736207962036
#
# current second:  119
# no mirror predicted label:  6  score: 0.4696060121059418
# filled predicted label:  6  score: 0.44721317291259766
# mirror predicted label:  0  score: 0.22
#
# current second:  120
# no mirror predicted label:  6  score: 0.4846929609775543
# filled predicted label:  6  score: 0.4514157772064209
# mirror predicted label:  5  score: 0.23460468649864197
#
# current second:  121
# no mirror predicted label:  6  score: 0.4866655766963959
# filled predicted label:  6  score: 0.448991060256958
# mirror predicted label:  5  score: 0.2209332138299942
#
# current second:  122
# no mirror predicted label:  6  score: 0.48944124579429626
# filled predicted label:  6  score: 0.4405905604362488
# mirror predicted label:  0  score: 0.22
#
# current second:  123
# no mirror predicted label:  6  score: 0.48676612973213196
# filled predicted label:  6  score: 0.43834593892097473
# mirror predicted label:  7  score: 0.24082551896572113
#
# current second:  124
# no mirror predicted label:  6  score: 0.4849834144115448
# filled predicted label:  6  score: 0.4487541615962982
# mirror predicted label:  0  score: 0.22
#
# current second:  125
# no mirror predicted label:  6  score: 0.48256340622901917
# filled predicted label:  6  score: 0.43472903966903687
# mirror predicted label:  7  score: 0.30602169036865234
#
# current second:  126
# no mirror predicted label:  6  score: 0.48116469383239746
# filled predicted label:  6  score: 0.4462279975414276
# mirror predicted label:  0  score: 0.22
#
# current second:  127
# no mirror predicted label:  6  score: 0.47925931215286255
# filled predicted label:  6  score: 0.4461183547973633
# mirror predicted label:  0  score: 0.22
#
# current second:  128
# no mirror predicted label:  6  score: 0.4780130386352539
# filled predicted label:  6  score: 0.4481341540813446
# mirror predicted label:  0  score: 0.22
#
# current second:  129
# no mirror predicted label:  6  score: 0.47623395919799805
# filled predicted label:  6  score: 0.4381774663925171
# mirror predicted label:  0  score: 0.22
#
# current second:  130
# no mirror predicted label:  6  score: 0.47478845715522766
# filled predicted label:  6  score: 0.43567967414855957
# mirror predicted label:  0  score: 0.22
#
# current second:  131
# no mirror predicted label:  6  score: 0.47241464257240295
# filled predicted label:  6  score: 0.42297685146331787
# mirror predicted label:  7  score: 0.5143216848373413
#
# current second:  132
# no mirror predicted label:  6  score: 0.4702933728694916
# filled predicted label:  7  score: 0.45577171444892883
# mirror predicted label:  7  score: 0.5508151054382324
#
# current second:  133
# no mirror predicted label:  6  score: 0.4676547646522522
# filled predicted label:  7  score: 0.8525939583778381
# mirror predicted label:  7  score: 0.8297411799430847
#
# current second:  134
# no mirror predicted label:  6  score: 0.46578431129455566
# filled predicted label:  7  score: 0.6569406986236572
# mirror predicted label:  7  score: 0.5932042002677917
#
# current second:  135
# no mirror predicted label:  7  score: 0.23797345161437988
# filled predicted label:  7  score: 0.5184901356697083
# mirror predicted label:  7  score: 0.5261148810386658
#
# current second:  136
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  7  score: 0.8185205459594727
# mirror predicted label:  7  score: 0.6724317669868469
#
# current second:  137
# no mirror predicted label:  7  score: 0.48738163709640503
# filled predicted label:  7  score: 0.5290240049362183
# mirror predicted label:  7  score: 0.5827465653419495
#
# current second:  138
# no mirror predicted label:  7  score: 0.5043627023696899
# filled predicted label:  7  score: 0.7277806401252747
# mirror predicted label:  7  score: 0.73206627368927
#
# current second:  139
# no mirror predicted label:  7  score: 0.47435426712036133
# filled predicted label:  7  score: 0.7683000564575195
# mirror predicted label:  7  score: 0.6939711570739746
#
# current second:  140
# no mirror predicted label:  7  score: 0.46996375918388367
# filled predicted label:  7  score: 0.634833812713623
# mirror predicted label:  16  score: 0.23679567873477936
#
# current second:  141
# no mirror predicted label:  7  score: 0.4260454475879669
# filled predicted label:  7  score: 0.6676491498947144
# mirror predicted label:  7  score: 0.2987712621688843
#
# current second:  142
# no mirror predicted label:  7  score: 0.4930475950241089
# filled predicted label:  7  score: 0.8142013549804688
# mirror predicted label:  7  score: 0.7516953349113464
#
# current second:  143
# no mirror predicted label:  7  score: 0.4921760857105255
# filled predicted label:  7  score: 0.6773998141288757
# mirror predicted label:  7  score: 0.7076520323753357
#
# current second:  144
# no mirror predicted label:  7  score: 0.560788631439209
# filled predicted label:  7  score: 0.8169386386871338
# mirror predicted label:  7  score: 0.7343508005142212
#
# current second:  145
# no mirror predicted label:  7  score: 0.6177846789360046
# filled predicted label:  7  score: 0.7124790549278259
# mirror predicted label:  7  score: 0.35741275548934937
#
# current second:  146
# no mirror predicted label:  7  score: 0.6158190965652466
# filled predicted label:  7  score: 0.6382583379745483
# mirror predicted label:  7  score: 0.34474581480026245
#
# current second:  147
# no mirror predicted label:  7  score: 0.593424379825592
# filled predicted label:  7  score: 0.6654948592185974
# mirror predicted label:  7  score: 0.3515847325325012
#
# current second:  148
# no mirror predicted label:  7  score: 0.6275950074195862
# filled predicted label:  7  score: 0.6570181250572205
# mirror predicted label:  7  score: 0.26180335879325867
#
# current second:  149
# no mirror predicted label:  7  score: 0.6431931257247925
# filled predicted label:  7  score: 0.6635434627532959
# mirror predicted label:  7  score: 0.26735877990722656
#
# current second:  150
# no mirror predicted label:  7  score: 0.6462349891662598
# filled predicted label:  7  score: 0.6637108325958252
# mirror predicted label:  7  score: 0.3122241795063019
#
# current second:  151
# no mirror predicted label:  7  score: 0.6470313668251038
# filled predicted label:  7  score: 0.664009153842926
# mirror predicted label:  7  score: 0.4130532443523407
#
# current second:  152
# no mirror predicted label:  7  score: 0.6472374796867371
# filled predicted label:  7  score: 0.6649925112724304
# mirror predicted label:  7  score: 0.43418341875076294
#
# current second:  153
# no mirror predicted label:  7  score: 0.649677038192749
# filled predicted label:  7  score: 0.6651407480239868
# mirror predicted label:  7  score: 0.3696112334728241
#
# current second:  154
# no mirror predicted label:  7  score: 0.6498878002166748
# filled predicted label:  7  score: 0.665701150894165
# mirror predicted label:  16  score: 0.30696529150009155
#
# current second:  155
# no mirror predicted label:  7  score: 0.6505944132804871
# filled predicted label:  7  score: 0.6654518246650696
# mirror predicted label:  7  score: 0.30914607644081116
#
# current second:  156
# no mirror predicted label:  7  score: 0.6506428122520447
# filled predicted label:  7  score: 0.6654817461967468
# mirror predicted label:  7  score: 0.30945897102355957
#
# current second:  157
# no mirror predicted label:  7  score: 0.6528454422950745
# filled predicted label:  7  score: 0.6663476824760437
# mirror predicted label:  7  score: 0.2532804012298584
#
# current second:  158
# no mirror predicted label:  7  score: 0.653038740158081
# filled predicted label:  7  score: 0.6669692397117615
# mirror predicted label:  7  score: 0.30234867334365845
#
# current second:  159
# no mirror predicted label:  7  score: 0.6537606120109558
# filled predicted label:  7  score: 0.6685816049575806
# mirror predicted label:  7  score: 0.35945361852645874
#
# current second:  160
# no mirror predicted label:  7  score: 0.6539931297302246
# filled predicted label:  7  score: 0.6688839197158813
# mirror predicted label:  7  score: 0.3236396610736847
#
# current second:  161
# no mirror predicted label:  7  score: 0.6561591625213623
# filled predicted label:  7  score: 0.6705293655395508
# mirror predicted label:  7  score: 0.3523769676685333
#
# current second:  162
# no mirror predicted label:  7  score: 0.6565037369728088
# filled predicted label:  7  score: 0.6711360216140747
# mirror predicted label:  16  score: 0.35983356833457947
#
# current second:  163
# no mirror predicted label:  7  score: 0.6572418808937073
# filled predicted label:  7  score: 0.6709774732589722
# mirror predicted label:  16  score: 0.36212870478630066
#
# current second:  164
# no mirror predicted label:  7  score: 0.6572927832603455
# filled predicted label:  7  score: 0.6711554527282715
# mirror predicted label:  7  score: 0.416847288608551
#
# current second:  165
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  7  score: 0.2595027983188629
# mirror predicted label:  7  score: 0.38531431555747986
#
# current second:  166
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  7  score: 0.3359546959400177
#
# current second:  167
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  16  score: 0.22784802317619324
# mirror predicted label:  7  score: 0.3469604551792145
#
# current second:  168
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  8  score: 0.2755100429058075
# mirror predicted label:  7  score: 0.3498033881187439
#
# current second:  169
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  7  score: 0.3335079848766327
#
# current second:  170
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  7  score: 0.3594663739204407
#
# current second:  171
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  7  score: 0.37031078338623047
#
# current second:  172
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  7  score: 0.37092798948287964
#
# current second:  173
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  7  score: 0.2996695935726166
#
# current second:  174
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  7  score: 0.28098347783088684
#
# current second:  175
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  7  score: 0.24585600197315216
# mirror predicted label:  7  score: 0.28368115425109863
#
# current second:  176
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  7  score: 0.291119784116745
#
# current second:  177
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  7  score: 0.2260001003742218
# mirror predicted label:  7  score: 0.3125516474246979
#
# current second:  178
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  7  score: 0.33227652311325073
# mirror predicted label:  7  score: 0.3563435673713684
#
# current second:  179
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  7  score: 0.2504587471485138
# mirror predicted label:  7  score: 0.3105476498603821
#
# current second:  180
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  8  score: 0.25688084959983826
# mirror predicted label:  7  score: 0.26930275559425354
#
# current second:  181
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  7  score: 0.2597061097621918
#
# current second:  182
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  8  score: 0.2562406063079834
# mirror predicted label:  8  score: 0.2500501275062561
#
# current second:  183
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  8  score: 0.5493025779724121
# mirror predicted label:  8  score: 0.6145550608634949
#
# current second:  184
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  8  score: 0.5502349734306335
# mirror predicted label:  8  score: 0.5194456577301025
#
# current second:  185
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  8  score: 0.5160502791404724
# mirror predicted label:  8  score: 0.48264914751052856
#
# current second:  186
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  8  score: 0.5093596577644348
# mirror predicted label:  8  score: 0.4352741241455078
#
# current second:  187
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  8  score: 0.4462323784828186
# mirror predicted label:  8  score: 0.3630078136920929
#
# current second:  188
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  8  score: 0.41758039593696594
# mirror predicted label:  8  score: 0.44928234815597534
#
# current second:  189
# no mirror predicted label:  8  score: 0.22504553198814392
# filled predicted label:  8  score: 0.42389315366744995
# mirror predicted label:  8  score: 0.3516300618648529
#
# current second:  190
# no mirror predicted label:  8  score: 0.22933995723724365
# filled predicted label:  8  score: 0.4154125154018402
# mirror predicted label:  8  score: 0.39164167642593384
#
# current second:  191
# no mirror predicted label:  8  score: 0.2241041660308838
# filled predicted label:  8  score: 0.38377219438552856
# mirror predicted label:  8  score: 0.34647610783576965
#
# current second:  192
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  8  score: 0.36088380217552185
# mirror predicted label:  8  score: 0.3328843116760254
#
# current second:  193
# no mirror predicted label:  8  score: 0.31076136231422424
# filled predicted label:  8  score: 0.6696329116821289
# mirror predicted label:  8  score: 0.6249290108680725
#
# current second:  194
# no mirror predicted label:  8  score: 0.3048843443393707
# filled predicted label:  8  score: 0.5250526666641235
# mirror predicted label:  8  score: 0.48204994201660156
#
# current second:  195
# no mirror predicted label:  8  score: 0.31444278359413147
# filled predicted label:  8  score: 0.5460647344589233
# mirror predicted label:  8  score: 0.47117096185684204
#
# current second:  196
# no mirror predicted label:  8  score: 0.3017241954803467
# filled predicted label:  8  score: 0.5106622576713562
# mirror predicted label:  8  score: 0.42752325534820557
#
# current second:  197
# no mirror predicted label:  8  score: 0.35300323367118835
# filled predicted label:  8  score: 0.5605519413948059
# mirror predicted label:  8  score: 0.47600528597831726
#
# current second:  198
# no mirror predicted label:  8  score: 0.33795347809791565
# filled predicted label:  8  score: 0.4205615818500519
# mirror predicted label:  8  score: 0.36548763513565063
#
# current second:  199
# no mirror predicted label:  8  score: 0.350521981716156
# filled predicted label:  8  score: 0.48159918189048767
# mirror predicted label:  8  score: 0.3906906843185425
#
# current second:  200
# no mirror predicted label:  8  score: 0.3311845660209656
# filled predicted label:  8  score: 0.3818925619125366
# mirror predicted label:  8  score: 0.3348682224750519
#
# current second:  201
# no mirror predicted label:  8  score: 0.3792388141155243
# filled predicted label:  8  score: 0.5216279625892639
# mirror predicted label:  8  score: 0.4515465199947357
#
# current second:  202
# no mirror predicted label:  8  score: 0.35742929577827454
# filled predicted label:  8  score: 0.4509199857711792
# mirror predicted label:  8  score: 0.38546231389045715
#
# current second:  203
# no mirror predicted label:  8  score: 0.3513430655002594
# filled predicted label:  8  score: 0.41261062026023865
# mirror predicted label:  8  score: 0.34618130326271057
#
# current second:  204
# no mirror predicted label:  8  score: 0.347186416387558
# filled predicted label:  8  score: 0.6124648451805115
# mirror predicted label:  8  score: 0.5537669062614441
#
# current second:  205
# no mirror predicted label:  8  score: 0.4140011966228485
# filled predicted label:  8  score: 0.5261411070823669
# mirror predicted label:  8  score: 0.41653192043304443
#
# current second:  206
# no mirror predicted label:  8  score: 0.41128578782081604
# filled predicted label:  8  score: 0.5241764783859253
# mirror predicted label:  8  score: 0.43173789978027344
#
# current second:  207
# no mirror predicted label:  8  score: 0.42021092772483826
# filled predicted label:  8  score: 0.4768761992454529
# mirror predicted label:  8  score: 0.39072418212890625
#
# current second:  208
# no mirror predicted label:  8  score: 0.4184696078300476
# filled predicted label:  8  score: 0.5289372801780701
# mirror predicted label:  8  score: 0.41021788120269775
#
# current second:  209
# no mirror predicted label:  8  score: 0.4362843632698059
# filled predicted label:  8  score: 0.5274466872215271
# mirror predicted label:  8  score: 0.40755248069763184
#
# current second:  210
# no mirror predicted label:  8  score: 0.437690407037735
# filled predicted label:  8  score: 0.5472254157066345
# mirror predicted label:  8  score: 0.4277392327785492
#
# current second:  211
# no mirror predicted label:  8  score: 0.4464704394340515
# filled predicted label:  8  score: 0.5152921676635742
# mirror predicted label:  8  score: 0.3933083117008209
#
# current second:  212
# no mirror predicted label:  8  score: 0.44376346468925476
# filled predicted label:  8  score: 0.5291978716850281
# mirror predicted label:  8  score: 0.4316774308681488
#
# current second:  213
# no mirror predicted label:  8  score: 0.4625731110572815
# filled predicted label:  8  score: 0.7165622711181641
# mirror predicted label:  8  score: 0.6651729345321655
#
# current second:  214
# no mirror predicted label:  8  score: 0.49151167273521423
# filled predicted label:  8  score: 0.6581831574440002
# mirror predicted label:  8  score: 0.583381712436676
#
# current second:  215
# no mirror predicted label:  8  score: 0.4783128798007965
# filled predicted label:  8  score: 0.5608486533164978
# mirror predicted label:  8  score: 0.5382513999938965
#
# current second:  216
# no mirror predicted label:  8  score: 0.5139750838279724
# filled predicted label:  8  score: 0.6697109937667847
# mirror predicted label:  8  score: 0.675219714641571
#
# current second:  217
# no mirror predicted label:  8  score: 0.5164188742637634
# filled predicted label:  8  score: 0.5409676432609558
# mirror predicted label:  8  score: 0.6354619264602661
#
# current second:  218
# no mirror predicted label:  8  score: 0.5062890648841858
# filled predicted label:  8  score: 0.6351224184036255
# mirror predicted label:  8  score: 0.6825189590454102
#
# current second:  219
# no mirror predicted label:  8  score: 0.49703294038772583
# filled predicted label:  8  score: 0.6175529360771179
# mirror predicted label:  8  score: 0.5295177698135376
#
# current second:  220
# no mirror predicted label:  8  score: 0.49711495637893677
# filled predicted label:  8  score: 0.497252494096756
# mirror predicted label:  8  score: 0.4906073212623596
#
# current second:  221
# no mirror predicted label:  8  score: 0.4974818229675293
# filled predicted label:  8  score: 0.49748286604881287
# mirror predicted label:  0  score: 0.22
#
# current second:  222
# no mirror predicted label:  8  score: 0.4973334074020386
# filled predicted label:  8  score: 0.4972071051597595
# mirror predicted label:  0  score: 0.22
#
# current second:  223
# no mirror predicted label:  8  score: 0.49744147062301636
# filled predicted label:  8  score: 0.49719202518463135
# mirror predicted label:  0  score: 0.22
#
# current second:  224
# no mirror predicted label:  8  score: 0.49718859791755676
# filled predicted label:  8  score: 0.4967579245567322
# mirror predicted label:  0  score: 0.22
#
# current second:  225
# no mirror predicted label:  8  score: 0.49810901284217834
# filled predicted label:  8  score: 0.497406005859375
# mirror predicted label:  0  score: 0.22
#
# current second:  226
# no mirror predicted label:  8  score: 0.49791955947875977
# filled predicted label:  8  score: 0.4973706007003784
# mirror predicted label:  0  score: 0.22
#
# current second:  227
# no mirror predicted label:  8  score: 0.4979121685028076
# filled predicted label:  8  score: 0.4975421130657196
# mirror predicted label:  0  score: 0.22
#
# current second:  228
# no mirror predicted label:  8  score: 0.49759867787361145
# filled predicted label:  8  score: 0.49697187542915344
# mirror predicted label:  0  score: 0.22
#
# current second:  229
# no mirror predicted label:  8  score: 0.4978283643722534
# filled predicted label:  8  score: 0.49708762764930725
# mirror predicted label:  0  score: 0.22
#
# current second:  230
# no mirror predicted label:  8  score: 0.49766209721565247
# filled predicted label:  8  score: 0.4968680739402771
# mirror predicted label:  0  score: 0.22
#
# current second:  231
# no mirror predicted label:  8  score: 0.49770915508270264
# filled predicted label:  8  score: 0.49726760387420654
# mirror predicted label:  0  score: 0.22
#
# current second:  232
# no mirror predicted label:  8  score: 0.49727219343185425
# filled predicted label:  8  score: 0.49685338139533997
# mirror predicted label:  0  score: 0.22
#
# current second:  233
# no mirror predicted label:  8  score: 0.4980103671550751
# filled predicted label:  8  score: 0.4973357021808624
# mirror predicted label:  0  score: 0.22
#
# current second:  234
# no mirror predicted label:  8  score: 0.4978337287902832
# filled predicted label:  8  score: 0.49710729718208313
# mirror predicted label:  0  score: 0.22
#
# current second:  235
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  236
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  237
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  238
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  239
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  240
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  241
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  242
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  243
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  244
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  245
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  246
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  247
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  248
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  249
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  250
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  251
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  252
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  253
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  254
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  255
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  256
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  257
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  10  score: 0.5799354314804077
# mirror predicted label:  10  score: 0.4349720776081085
#
# current second:  258
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  10  score: 0.6428373456001282
# mirror predicted label:  10  score: 0.5153289437294006
#
# current second:  259
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  10  score: 0.6270273327827454
# mirror predicted label:  10  score: 0.5566954612731934
#
# current second:  260
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  261
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  10  score: 0.7832395434379578
# mirror predicted label:  10  score: 0.7270944118499756
#
# current second:  262
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  10  score: 0.7998335361480713
# mirror predicted label:  10  score: 0.7512089610099792
#
# current second:  263
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  10  score: 0.7647495865821838
# mirror predicted label:  10  score: 0.7649751901626587
#
# current second:  264
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  10  score: 0.7279748320579529
# mirror predicted label:  10  score: 0.8100946545600891
#
# current second:  265
# no mirror predicted label:  10  score: 0.48096922039985657
# filled predicted label:  10  score: 0.8242035508155823
# mirror predicted label:  10  score: 0.8313055634498596
#
# current second:  266
# no mirror predicted label:  10  score: 0.5014622211456299
# filled predicted label:  10  score: 0.8392904996871948
# mirror predicted label:  10  score: 0.8454128503799438
#
# current second:  267
# no mirror predicted label:  10  score: 0.4846588969230652
# filled predicted label:  10  score: 0.8303407430648804
# mirror predicted label:  10  score: 0.8454693555831909
#
# current second:  268
# no mirror predicted label:  10  score: 0.5158673524856567
# filled predicted label:  10  score: 0.8427219986915588
# mirror predicted label:  10  score: 0.8523523211479187
#
# current second:  269
# no mirror predicted label:  10  score: 0.6144393086433411
# filled predicted label:  10  score: 0.9045188426971436
# mirror predicted label:  10  score: 0.851753294467926
#
# current second:  270
# no mirror predicted label:  10  score: 0.6807326078414917
# filled predicted label:  10  score: 0.875599205493927
# mirror predicted label:  10  score: 0.8561744689941406
#
# current second:  271
# no mirror predicted label:  10  score: 0.6440378427505493
# filled predicted label:  10  score: 0.8601924777030945
# mirror predicted label:  10  score: 0.8837888240814209
#
# current second:  272
# no mirror predicted label:  10  score: 0.6589585542678833
# filled predicted label:  10  score: 0.8390990495681763
# mirror predicted label:  10  score: 0.8653242588043213
#
# current second:  273
# no mirror predicted label:  10  score: 0.5791879892349243
# filled predicted label:  10  score: 0.849742591381073
# mirror predicted label:  10  score: 0.9040078520774841
#
# current second:  274
# ...
# filled predicted label:  16  score: 0.4282152056694031
# mirror predicted label:  16  score: 0.43945586681365967
#
# current second:  669
# no mirror predicted label:  16  score: 0.2736791670322418
# filled predicted label:  16  score: 0.4627947211265564
# mirror predicted label:  16  score: 0.4553350806236267
#
# current second:  670
# no mirror predicted label:  16  score: 0.2891932427883148
# filled predicted label:  16  score: 0.3848271369934082
# mirror predicted label:  16  score: 0.4267938733100891
#
# current second:  671
# no mirror predicted label:  16  score: 0.2690262198448181
# filled predicted label:  16  score: 0.3761494755744934
# mirror predicted label:  16  score: 0.39454784989356995
#
# current second:  672
# no mirror predicted label:  16  score: 0.2628129720687866
# filled predicted label:  16  score: 0.39176979660987854
# mirror predicted label:  16  score: 0.38770389556884766
#
# current second:  673
# no mirror predicted label:  16  score: 0.34683752059936523
# filled predicted label:  16  score: 0.4784080684185028
# mirror predicted label:  16  score: 0.46163246035575867
#
# current second:  674
# no mirror predicted label:  16  score: 0.3440586030483246
# filled predicted label:  16  score: 0.4006182551383972
# mirror predicted label:  16  score: 0.4164523482322693
#
# current second:  675
# no mirror predicted label:  16  score: 0.33855077624320984
# filled predicted label:  16  score: 0.39918053150177
# mirror predicted label:  16  score: 0.41836270689964294
#
# current second:  676
# no mirror predicted label:  16  score: 0.3157018721103668
# filled predicted label:  16  score: 0.3414117395877838
# mirror predicted label:  16  score: 0.3725437521934509
#
# current second:  677
# no mirror predicted label:  16  score: 0.3542598485946655
# filled predicted label:  16  score: 0.4721159040927887
# mirror predicted label:  16  score: 0.45115944743156433
#
# current second:  678
# no mirror predicted label:  16  score: 0.37880823016166687
# filled predicted label:  16  score: 0.33709657192230225
# mirror predicted label:  16  score: 0.37148168683052063
#
# current second:  679
# no mirror predicted label:  16  score: 0.33023884892463684
# filled predicted label:  16  score: 0.32100358605384827
# mirror predicted label:  16  score: 0.36387455463409424
#
# current second:  680
# no mirror predicted label:  16  score: 0.2847783863544464
# filled predicted label:  16  score: 0.31785914301872253
# mirror predicted label:  16  score: 0.36297735571861267
#
# current second:  681
# no mirror predicted label:  16  score: 0.27813243865966797
# filled predicted label:  16  score: 0.31803929805755615
# mirror predicted label:  16  score: 0.35616573691368103
#
# current second:  682
# no mirror predicted label:  16  score: 0.28094375133514404
# filled predicted label:  16  score: 0.319411039352417
# mirror predicted label:  16  score: 0.3632211685180664
#
# current second:  683
# no mirror predicted label:  16  score: 0.27950796484947205
# filled predicted label:  16  score: 0.32226017117500305
# mirror predicted label:  16  score: 0.3705783188343048
#
# current second:  684
# no mirror predicted label:  16  score: 0.2800286114215851
# filled predicted label:  16  score: 0.3210678994655609
# mirror predicted label:  16  score: 0.36714184284210205
#
# current second:  685
# no mirror predicted label:  16  score: 0.2834553122520447
# filled predicted label:  16  score: 0.32119616866111755
# mirror predicted label:  16  score: 0.36966389417648315
#
# current second:  686
# no mirror predicted label:  16  score: 0.28485509753227234
# filled predicted label:  16  score: 0.32066991925239563
# mirror predicted label:  16  score: 0.36549538373947144
#
# current second:  687
# no mirror predicted label:  16  score: 0.2855633795261383
# filled predicted label:  16  score: 0.31779733300209045
# mirror predicted label:  16  score: 0.36295101046562195
#
# current second:  688
# no mirror predicted label:  16  score: 0.28971928358078003
# filled predicted label:  16  score: 0.31969210505485535
# mirror predicted label:  16  score: 0.3633032441139221
#
# current second:  689
# no mirror predicted label:  16  score: 0.3030046224594116
# filled predicted label:  16  score: 0.32093748450279236
# mirror predicted label:  16  score: 0.3573852777481079
#
# current second:  690
# no mirror predicted label:  16  score: 0.3078277111053467
# filled predicted label:  16  score: 0.320607453584671
# mirror predicted label:  16  score: 0.3642783761024475
#
# current second:  691
# no mirror predicted label:  16  score: 0.3044508695602417
# filled predicted label:  16  score: 0.32082244753837585
# mirror predicted label:  16  score: 0.3686978816986084
#
# current second:  692
# no mirror predicted label:  16  score: 0.30828437209129333
# filled predicted label:  16  score: 0.32069286704063416
# mirror predicted label:  16  score: 0.3653146028518677
#
# current second:  693
# no mirror predicted label:  16  score: 0.30474090576171875
# filled predicted label:  16  score: 0.32142359018325806
# mirror predicted label:  16  score: 0.36840903759002686
#
# current second:  694
# no mirror predicted label:  16  score: 0.30877166986465454
# filled predicted label:  16  score: 0.3211670219898224
# mirror predicted label:  16  score: 0.36417603492736816
#
# current second:  695
# no mirror predicted label:  16  score: 0.3069503903388977
# filled predicted label:  16  score: 0.3216305375099182
# mirror predicted label:  16  score: 0.36455461382865906
#
# current second:  696
# no mirror predicted label:  16  score: 0.31564515829086304
# filled predicted label:  16  score: 0.32132405042648315
# mirror predicted label:  16  score: 0.36435583233833313
#
# current second:  697
# no mirror predicted label:  16  score: 0.31682199239730835
# filled predicted label:  16  score: 0.3215758502483368
# mirror predicted label:  16  score: 0.3576991856098175
#
# current second:  698
# no mirror predicted label:  16  score: 0.317015677690506
# filled predicted label:  16  score: 0.32194623351097107
# mirror predicted label:  16  score: 0.3649826645851135
#
# current second:  699
# no mirror predicted label:  16  score: 0.31730687618255615
# filled predicted label:  16  score: 0.32216542959213257
# mirror predicted label:  16  score: 0.369060754776001
#
# current second:  700
# no mirror predicted label:  16  score: 0.3173191249370575
# filled predicted label:  16  score: 0.32213374972343445
# mirror predicted label:  16  score: 0.3658714294433594
#
# current second:  701
# no mirror predicted label:  16  score: 0.31772497296333313
# filled predicted label:  16  score: 0.3227914273738861
# mirror predicted label:  16  score: 0.36886101961135864
#
# current second:  702
# no mirror predicted label:  16  score: 0.3178514540195465
# filled predicted label:  16  score: 0.3226478099822998
# mirror predicted label:  16  score: 0.36496487259864807
#
# current second:  703
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  16  score: 0.3229028582572937
# mirror predicted label:  16  score: 0.36521223187446594
#
# current second:  704
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  16  score: 0.3229717016220093
# mirror predicted label:  16  score: 0.36415889859199524
#
# current second:  705
# no mirror predicted label:  16  score: 0.31880423426628113
# filled predicted label:  5  score: 0.7736379504203796
# mirror predicted label:  5  score: 0.7569356560707092
#
# current second:  706
# no mirror predicted label:  16  score: 0.31889453530311584
# filled predicted label:  16  score: 0.32429003715515137
# mirror predicted label:  16  score: 0.3652237057685852
#
# current second:  707
# no mirror predicted label:  16  score: 0.3191700875759125
# filled predicted label:  16  score: 0.3241238296031952
# mirror predicted label:  5  score: 0.3772875666618347
#
# current second:  708
# no mirror predicted label:  16  score: 0.3192242383956909
# filled predicted label:  16  score: 0.324145644903183
# mirror predicted label:  16  score: 0.365608274936676
#
# current second:  709
# no mirror predicted label:  16  score: 0.31972214579582214
# filled predicted label:  16  score: 0.3248465359210968
# mirror predicted label:  16  score: 0.3687637150287628
#
# current second:  710
# no mirror predicted label:  16  score: 0.3197828233242035
# filled predicted label:  16  score: 0.32460013031959534
# mirror predicted label:  16  score: 0.36470451951026917
#
# current second:  711
# no mirror predicted label:  16  score: 0.32002002000808716
# filled predicted label:  16  score: 0.3244144320487976
# mirror predicted label:  16  score: 0.36459726095199585
#
# current second:  712
# no mirror predicted label:  16  score: 0.32003605365753174
# filled predicted label:  16  score: 0.32520702481269836
# mirror predicted label:  16  score: 0.36495769023895264
#
# current second:  713
# no mirror predicted label:  16  score: 0.3206638991832733
# filled predicted label:  16  score: 0.3257843554019928
# mirror predicted label:  16  score: 0.35871922969818115
#
# current second:  714
# no mirror predicted label:  16  score: 0.32075241208076477
# filled predicted label:  16  score: 0.32570165395736694
# mirror predicted label:  16  score: 0.3654266893863678
#
# current second:  715
# no mirror predicted label:  16  score: 0.321090430021286
# filled predicted label:  16  score: 0.32597172260284424
# mirror predicted label:  16  score: 0.3698541522026062
#
# current second:  716
# no mirror predicted label:  16  score: 0.3211226761341095
# filled predicted label:  16  score: 0.32581502199172974
# mirror predicted label:  16  score: 0.36636021733283997
#
# current second:  717
# no mirror predicted label:  16  score: 0.3215602934360504
# filled predicted label:  16  score: 0.3259885907173157
# mirror predicted label:  16  score: 0.36903977394104004
#
# current second:  718
# no mirror predicted label:  16  score: 0.32162725925445557
# filled predicted label:  16  score: 0.3262633681297302
# mirror predicted label:  16  score: 0.3655143976211548
#
# current second:  719
# no mirror predicted label:  16  score: 0.32193952798843384
# filled predicted label:  16  score: 0.3265518248081207
# mirror predicted label:  16  score: 0.3658634424209595
#
# current second:  720
# no mirror predicted label:  16  score: 0.3219626843929291
# filled predicted label:  16  score: 0.32650038599967957
# mirror predicted label:  16  score: 0.3659833073616028
#
# current second:  721
# no mirror predicted label:  16  score: 0.3224828243255615
# filled predicted label:  16  score: 0.3268268406391144
# mirror predicted label:  16  score: 0.3592278063297272
#
# current second:  722
# no mirror predicted label:  16  score: 0.32254233956336975
# filled predicted label:  16  score: 0.32697629928588867
# mirror predicted label:  16  score: 0.3660733699798584
#
# current second:  723
# no mirror predicted label:  16  score: 0.3228447735309601
# filled predicted label:  16  score: 0.32725852727890015
# mirror predicted label:  16  score: 0.3701515793800354
#
# current second:  724
# no mirror predicted label:  16  score: 0.3228614628314972
# filled predicted label:  16  score: 0.3273802697658539
# mirror predicted label:  16  score: 0.36678558588027954
#
# current second:  725
# no mirror predicted label:  16  score: 0.323220431804657
# filled predicted label:  16  score: 0.3280014395713806
# mirror predicted label:  16  score: 0.3694963753223419
#
# current second:  726
# no mirror predicted label:  16  score: 0.3233356475830078
# filled predicted label:  16  score: 0.32781192660331726
# mirror predicted label:  16  score: 0.36551252007484436
#
# current second:  727
# no mirror predicted label:  16  score: 0.32359597086906433
# filled predicted label:  16  score: 0.3282953202724457
# mirror predicted label:  16  score: 0.3659645915031433
#
# current second:  728
# no mirror predicted label:  16  score: 0.3236296772956848
# filled predicted label:  16  score: 0.3283994793891907
# mirror predicted label:  16  score: 0.36614054441452026
#
# current second:  729
# no mirror predicted label:  16  score: 0.324163019657135
# filled predicted label:  16  score: 0.3288823664188385
# mirror predicted label:  16  score: 0.3595256507396698
#
# current second:  730
# no mirror predicted label:  16  score: 0.32427120208740234
# filled predicted label:  16  score: 0.3290061354637146
# mirror predicted label:  16  score: 0.3663017749786377
#
# current second:  731
# no mirror predicted label:  16  score: 0.32453176379203796
# filled predicted label:  16  score: 0.32912081480026245
# mirror predicted label:  16  score: 0.37035638093948364
#
# current second:  732
# no mirror predicted label:  16  score: 0.32457777857780457
# filled predicted label:  16  score: 0.32917022705078125
# mirror predicted label:  16  score: 0.36698266863822937
#
# current second:  733
# no mirror predicted label:  16  score: 0.32497215270996094
# filled predicted label:  16  score: 0.32961010932922363
# mirror predicted label:  16  score: 0.3696011006832123
#
# current second:  734
# no mirror predicted label:  16  score: 0.32503339648246765
# filled predicted label:  16  score: 0.3295869827270508
# mirror predicted label:  16  score: 0.3656909167766571
#
# current second:  735
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  16  score: 0.32987940311431885
# mirror predicted label:  16  score: 0.36601319909095764
#
# current second:  736
# no mirror predicted label:  16  score: 0.32527321577072144
# filled predicted label:  16  score: 0.32984089851379395
# mirror predicted label:  16  score: 0.3661743998527527
#
# current second:  737
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  16  score: 0.3301471173763275
# mirror predicted label:  16  score: 0.35935118794441223
#
# current second:  738
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  16  score: 0.3302794396877289
# mirror predicted label:  16  score: 0.3661467432975769
#
# current second:  739
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  16  score: 0.33056139945983887
# mirror predicted label:  0  score: 0.22
#
# current second:  740
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  18  score: 0.415994793176651
# mirror predicted label:  18  score: 0.6669268608093262
#
# current second:  741
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  16  score: 0.3312497138977051
# mirror predicted label:  16  score: 0.36923354864120483
#
# current second:  742
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  16  score: 0.33117443323135376
# mirror predicted label:  16  score: 0.36520472168922424
#
# current second:  743
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  16  score: 0.3313957452774048
# mirror predicted label:  16  score: 0.36547282338142395
#
# current second:  744
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  16  score: 0.33177757263183594
# mirror predicted label:  16  score: 0.36584922671318054
#
# current second:  745
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  16  score: 0.3318635821342468
# mirror predicted label:  16  score: 0.3587630093097687
#
# current second:  746
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  18  score: 0.4279007911682129
# mirror predicted label:  18  score: 0.6691951751708984
#
# current second:  747
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  748
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  16  score: 0.3321966528892517
# mirror predicted label:  0  score: 0.22
#
# current second:  749
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  0  score: 0.22
# mirror predicted label:  0  score: 0.22
#
# current second:  750
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  16  score: 0.33336693048477173
# mirror predicted label:  0  score: 0.22
#
# current second:  751
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  16  score: 0.33288758993148804
# mirror predicted label:  0  score: 0.22
#
# current second:  752
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  11  score: 0.43122005462646484
# mirror predicted label:  11  score: 0.707530677318573
#
# current second:  753
# no mirror predicted label:  0  score: 0.22
# filled predicted label:  11  score: 0.5412801504135132
# mirror predicted label:  11  score: 0.666442334651947
#
# finished
# total time:  491

# %%
df[df["score"]>=0.22]
# Out:
#    video-id     t-start        t-end  label     score
# 0    test01   23.998512   139.150421     10  0.901110
# 1    test01  916.218018  1024.000000     10  0.894918
# 2    test01  306.380035   397.245392     15  0.772213
# 3    test01  659.538025   741.631104     15  0.762264
# 4    test01  150.395798   155.258194      4  0.758918
# 5    test01  899.757202   904.679565      4  0.690672
# 6    test01  510.535278   539.998108     11  0.666442
# 7    test01  783.475525   786.212402      4  0.639494
# 8    test01  268.491913   271.027039      4  0.614927
# 9    test01  290.328003   302.472351     14  0.538024
# 10   test01  198.732727   246.934418     11  0.501811
# 11   test01  276.094299   286.642090     13  0.448961
# 12   test01  418.464691   473.742615     16  0.357449
# 13   test01  809.902710   845.344421     11  0.332212
# 14   test01  603.212158   738.098572     15  0.315454
# 15   test01  617.186523   720.082397     16  0.282295
# 16   test01   63.620491   140.472321     10  0.253494

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

# %%
gt = pd.read_csv("/data/disk/LUO/test_only/r_tridet/TriDet/df_gt.csv")

# %%
accuracy_score(gt[gt["video_id"]=="test01.mp4"]["gt_labels"][-len(pred_list):],pure_pred_list[:])
# Out:
# 0.5099601593625498

# %%
x = gt[gt["video_id"]=="test01.mp4"][-len(pred_list):]

# %%
x["pred_labels"] = pred_list

# %%
x.to_csv("result_real_time.csv")

# %%
#Feature extraction configs
args = parse_args()
cfg = load_config(args)
cfg.USED_GPU = 4 #make sure it is same as device

#tridet_cfg = load_tridet_config("/data/disk/LUO/test_only/TriDet/configs/cataract_slowfast.yaml")
#ckpt_file = '/data/disk/LUO/epoch_110_best.pth.tar'

tridet_cfg = load_tridet_config("/data/disk/LUO/test_only/TriDet/configs/cataract_slowfast_reverse.yaml")
ckpt_file = '/data/disk/LUO/test_only/TriDet/ckpt/cataract_slowfast_reverse_reverse/epoch_080.pth.tar'

topk=-1
print_freq = 10
save_only = False

# fix the random seeds (this will fix everything)
_ = fix_random_seed(0, include_cuda=True)

# %%
extract_model = build_model(cfg).to(device)
extract_checkpoint = torch.load("/data/disk/LUO/slowfast/feature_extract/checkpoints/checkpoint_epoch_00130.pyth",map_location=device)
print("Loading from Feature Extraction Model ...")
extract_model.load_state_dict(extract_checkpoint['model_state'])
del extract_checkpoint
model = make_meta_arch(tridet_cfg['model_name'], **tridet_cfg['model'])
model = nn.DataParallel(model, device_ids=tridet_cfg['devices'])
print("=> loading checkpoint '{}'".format(ckpt_file))
checkpoint = torch.load(
    ckpt_file,
    map_location=lambda storage, loc: storage.cuda(tridet_cfg['devices'][0])
)
print("loading finish")
# load ema model instead
print("Loading from EMA model ...")
model.load_state_dict(checkpoint['state_dict_ema'])
del checkpoint
print("loading finish")
gt = pd.read_csv("/data/disk/LUO/test_only/r_tridet/TriDet/df_gt.csv")
dir_name = "/data/disk/LUO/cataract_test_video"
# Out:
# Loading from Feature Extraction Model ...
# => loading checkpoint '/data/disk/LUO/test_only/TriDet/ckpt/cataract_slowfast_reverse_reverse/epoch_080.pth.tar'
# loading finish
# Loading from EMA model ...
# loading finish

# %%
def main(vid,log_folder,threshold=0.1,num_fill=32):    
    print("Eval video: ",vid," ...")
    vid_path = os.path.join(dir_name,vid)
    device = "cuda:4"
    cap = cv2.VideoCapture(vid_path)
    sample_height = 256
    sample_width = 256
    count = 0
    seq_length = 32
    queue = deque(maxlen=32)
    ret = True
    frame_wise_feature = None
    idx = int(vid_path.split("/")[-1].split(".")[0].split("test")[-1])-1 #test01 -> 0
    dict_db,label_dict = _load_json() #dict_db contains segments and labels
    current_db = dict_db[idx] #current test file json
    count_2 = 0 #count after queue is full
    # load tridet model
    # not ideal for multi GPU training, ok for now

    # load ckpt, reset epoch / best rmse


    pred_list = []
    score_list = []
    start = datetime.datetime.now()
    while ret:
        #print("count: ",count)
        
        ret,frame = cap.read()
        if not ret:
            print("finished")
            break
        height, width = frame.shape[:2]
        frame = cv2.resize(frame,(sample_height,sample_width),interpolation = cv2.INTER_LINEAR)
        queue.append(frame)
        if count<32:
            count+=1
            continue
        else:
            
            frames = np.stack(queue, axis=0)
            frames = pre_process_frame(frames)
            frame_list = pack_pathway_output(cfg, frames) #得到一个list,list[0]为(3,8,256,256),[1]为[3,32,256,256]分别表示slow和fast两条线
            frame_list[0] = frame_list[0].unsqueeze(0) #增加一个batch维度
            frame_list[1] = frame_list[1].unsqueeze(0)
            if count_2%30 == 0: #每30表示的是每30个frame，即每一秒取一次feature
                cur_second = count//30
                #print("current second: ",cur_second)
                if frame_wise_feature is None:
                    frame_wise_feature = test(extract_model,cfg,frame_list) #得到每32个frame为单位的一个feature，size大小为(1,2304)
                    #print("frame_wise_feture",frame_wise_feture.shape)
                    #print(test(cfg,frame_list))
                else:
                    #print("frame_wise_feture ",frame_wise_feture.shape)
                    cur_feature = test(extract_model,cfg,frame_list)
                    #print("cur_feature ",cur_feature.shape)
                    frame_wise_feature = np.concatenate((frame_wise_feature,cur_feature),axis=0)
                    #print(frame_wise_feture.shape)
                    #将frame_wise_feature 在dim 0 上concate起来，放入surgplan的eval方程
                
                
                #transfer input frame_wise_features into dictionary
                inputs = getitem(data_list=dict_db,features=frame_wise_feature, idx=idx,num_frames=len(frame_wise_feature))
                #ret = False
                #inference
                results = valid_one_epoch([mirror_feature(inputs,num_fill)],model=model)
                df = to_df(results)
                if inputs["feats"].size(1) == 1024:
                    pred_label,score = get_middle_label(df,[512-num_fill//2,512+num_fill//2],0.1)
                else:
                    pred_label,score = get_middle_label(df,[cur_second+num_fill-2,cur_second+num_fill],threshold)
                #print("predicted label: ",pred_label," score:",score)
                pred_list.append(pred_label)
                score_list.append(score)
            count+=1
            count_2 +=1 
    end = datetime.datetime.now()
    cap.release()
    print("total time: ", (end-start).seconds)
    acc = accuracy_score(gt[gt["video_id"]==vid]["gt_labels"][-len(pred_list):],pred_list[:])
    print("accuracy for vid: ",vid," is : ",acc)
    
    x = gt[gt["video_id"]==vid][-len(pred_list):]
    x["pred_labels"] = pred_list
    x["pred_scores"] = score_list

    csv_file = "./"+log_folder+"/result_real_time_"+vid+".csv"
    x.to_csv(csv_file)

# %%
cur_time = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+"_result"
os.mkdir(cur_time)
for i in os.listdir("/data/disk/LUO/cataract_test_video"):
    main(i,cur_time,threshold=0.18,num_fill=24)
# Out:
# Eval video:  test01.mp4  ...
# finished
# total time:  331
# accuracy for vid:  test01.mp4  is :  0.6427622841965471
# Eval video:  test02.mp4  ...
# finished
# total time:  845
# accuracy for vid:  test02.mp4  is :  0.4849137931034483
# Eval video:  test03.mp4  ...
# finished
# total time:  221
# accuracy for vid:  test03.mp4  is :  0.852882703777336
# Eval video:  test04.mp4  ...
# finished
# total time:  212
# accuracy for vid:  test04.mp4  is :  0.7577639751552795
# Eval video:  test05.mp4  ...
# finished
# total time:  208
# accuracy for vid:  test05.mp4  is :  0.7398720682302772
# Eval video:  test06.mp4  ...
# finished
# total time:  252
# accuracy for vid:  test06.mp4  is :  0.679646017699115
# Eval video:  test07.mp4  ...
# finished
# total time:  470
# accuracy for vid:  test07.mp4  is :  0.5480769230769231
# Eval video:  test08.mp4  ...
# finished
# total time:  191
# accuracy for vid:  test08.mp4  is :  0.744920993227991
# Eval video:  test09.mp4  ...
# finished
# total time:  282
# accuracy for vid:  test09.mp4  is :  0.751937984496124
# Eval video:  test10.mp4  ...
# finished
# total time:  248
# accuracy for vid:  test10.mp4  is :  0.7288732394366197
# Eval video:  test11.mp4  ...
# finished
# total time:  225
# accuracy for vid:  test11.mp4  is :  0.7602339181286549
# Eval video:  test12.mp4  ...
# finished
# total time:  169
# accuracy for vid:  test12.mp4  is :  0.7928388746803069
# Eval video:  test13.mp4  ...
# finished
# total time:  249
# accuracy for vid:  test13.mp4  is :  0.7859712230215827
# Eval video:  test14.mp4  ...
# finished
# total time:  169
# accuracy for vid:  test14.mp4  is :  0.7436548223350253
# Eval video:  test15.mp4  ...
# finished
# total time:  210
# accuracy for vid:  test15.mp4  is :  0.768595041322314
# Eval video:  test16.mp4  ...
# finished
# total time:  299
# accuracy for vid:  test16.mp4  is :  0.6891495601173021
# Eval video:  test17.mp4  ...
# finished
# total time:  217
# accuracy for vid:  test17.mp4  is :  0.6692759295499021
# Eval video:  test18.mp4  ...
# finished
# total time:  299
# accuracy for vid:  test18.mp4  is :  0.7281831187410587
# Eval video:  test19.mp4  ...
# finished
# total time:  317
# accuracy for vid:  test19.mp4  is :  0.7308743169398907
# Eval video:  test20.mp4  ...
# finished
# total time:  234
# accuracy for vid:  test20.mp4  is :  0.8146067415730337
# Eval video:  test21.mp4  ...
# finished
# total time:  206
# accuracy for vid:  test21.mp4  is :  0.79375
# Eval video:  test22.mp4  ...
# finished
# total time:  221
# accuracy for vid:  test22.mp4  is :  0.6632860040567952
# Eval video:  test23.mp4  ...
# finished
# total time:  231
# accuracy for vid:  test23.mp4  is :  0.8218390804597702
# Eval video:  test24.mp4  ...
# finished
# total time:  220
# accuracy for vid:  test24.mp4  is :  0.7771317829457365
# Eval video:  test25.mp4  ...
# finished
# total time:  265
# accuracy for vid:  test25.mp4  is :  0.6694915254237288

# %%
cur_time = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+"_result"
os.mkdir(cur_time)
for i in os.listdir("/data/disk/LUO/cataract_test_video"):
    main(i,cur_time,threshold=0.15,num_fill=32)
# Out:
# Eval video:  test01.mp4  ...
# finished
# total time:  321
# accuracy for vid:  test01.mp4  is :  0.7224435590969456
# Eval video:  test02.mp4  ...
# finished
# total time:  803
# accuracy for vid:  test02.mp4  is :  0.5102370689655172
# Eval video:  test03.mp4  ...
# finished
# total time:  211
# accuracy for vid:  test03.mp4  is :  0.852882703777336
# Eval video:  test04.mp4  ...
# finished
# total time:  198
# accuracy for vid:  test04.mp4  is :  0.7929606625258799
# Eval video:  test05.mp4  ...
# finished
# total time:  204
# accuracy for vid:  test05.mp4  is :  0.767590618336887
# Eval video:  test06.mp4  ...
# finished
# total time:  236
# accuracy for vid:  test06.mp4  is :  0.6991150442477876
# Eval video:  test07.mp4  ...
# finished
# total time:  429
# accuracy for vid:  test07.mp4  is :  0.5711538461538461
# Eval video:  test08.mp4  ...
# finished
# total time:  191
# accuracy for vid:  test08.mp4  is :  0.781038374717833
# Eval video:  test09.mp4  ...
# finished
# total time:  281
# accuracy for vid:  test09.mp4  is :  0.7441860465116279
# Eval video:  test10.mp4  ...
# finished
# total time:  245
# accuracy for vid:  test10.mp4  is :  0.7323943661971831
# Eval video:  test11.mp4  ...
# finished
# total time:  224
# accuracy for vid:  test11.mp4  is :  0.7543859649122807
# Eval video:  test12.mp4  ...
# finished
# total time:  169
# accuracy for vid:  test12.mp4  is :  0.8235294117647058
# Eval video:  test13.mp4  ...
# finished
# total time:  240
# accuracy for vid:  test13.mp4  is :  0.8003597122302158
# Eval video:  test14.mp4  ...
# finished
# total time:  158
# accuracy for vid:  test14.mp4  is :  0.7791878172588832
# Eval video:  test15.mp4  ...
# finished
# total time:  196
# accuracy for vid:  test15.mp4  is :  0.756198347107438
# Eval video:  test16.mp4  ...
# finished
# total time:  285
# accuracy for vid:  test16.mp4  is :  0.6994134897360704
# Eval video:  test17.mp4  ...
# finished
# total time:  205
# accuracy for vid:  test17.mp4  is :  0.7142857142857143
# Eval video:  test18.mp4  ...
# finished
# total time:  291
# accuracy for vid:  test18.mp4  is :  0.7052932761087267
# Eval video:  test19.mp4  ...
# finished
# total time:  306
# accuracy for vid:  test19.mp4  is :  0.7390710382513661
# Eval video:  test20.mp4  ...
# finished
# total time:  216
# accuracy for vid:  test20.mp4  is :  0.7771535580524345
# Eval video:  test21.mp4  ...
# finished
# total time:  196
# accuracy for vid:  test21.mp4  is :  0.8229166666666666
# Eval video:  test22.mp4  ...
# finished
# total time:  205
# accuracy for vid:  test22.mp4  is :  0.7302231237322515
# Eval video:  test23.mp4  ...
# finished
# total time:  230
# accuracy for vid:  test23.mp4  is :  0.8256704980842912
# Eval video:  test24.mp4  ...
# finished
# total time:  226
# accuracy for vid:  test24.mp4  is :  0.7713178294573644
# Eval video:  test25.mp4  ...
# finished
# total time:  253
# accuracy for vid:  test25.mp4  is :  0.688135593220339

# %%
ckpt_file = '/data/disk/LUO/test_only/TriDet/ckpt/cataract_slowfast_reverse_reverse/epoch_050.pth.tar'

extract_model = build_model(cfg).to(device)
extract_checkpoint = torch.load("/data/disk/LUO/slowfast/feature_extract/checkpoints/checkpoint_epoch_00130.pyth",map_location=device)
print("Loading from Feature Extraction Model ...")
extract_model.load_state_dict(extract_checkpoint['model_state'])
del extract_checkpoint
model = make_meta_arch(tridet_cfg['model_name'], **tridet_cfg['model'])
model = nn.DataParallel(model, device_ids=tridet_cfg['devices'])
print("=> loading checkpoint '{}'".format(ckpt_file))
checkpoint = torch.load(
    ckpt_file,
    map_location=lambda storage, loc: storage.cuda(tridet_cfg['devices'][0])
)
print("loading finish")
# load ema model instead
print("Loading from EMA model ...")
model.load_state_dict(checkpoint['state_dict_ema'])
del checkpoint
print("loading finish")
gt = pd.read_csv("/data/disk/LUO/test_only/r_tridet/TriDet/df_gt.csv")
dir_name = "/data/disk/LUO/cataract_test_video"

# %%
cur_time = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+"_result"
os.mkdir(cur_time)
for i in os.listdir("/data/disk/LUO/cataract_test_video"):
    main(i,cur_time,threshold=0.135,num_fill=32)
# Out:
# Eval video:  test01.mp4  ...
# finished
# total time:  320
# accuracy for vid:  test01.mp4  is :  0.7250996015936255
# Eval video:  test02.mp4  ...
# finished
# total time:  808
# accuracy for vid:  test02.mp4  is :  0.5043103448275862
# Eval video:  test03.mp4  ...
# finished
# total time:  203
# accuracy for vid:  test03.mp4  is :  0.8290258449304175
# Eval video:  test04.mp4  ...
# finished
# total time:  206
# accuracy for vid:  test04.mp4  is :  0.7743271221532091
# Eval video:  test05.mp4  ...
# finished
# total time:  197
# accuracy for vid:  test05.mp4  is :  0.7654584221748401
# Eval video:  test06.mp4  ...
# finished
# total time:  234
# accuracy for vid:  test06.mp4  is :  0.6761061946902654
# Eval video:  test07.mp4  ...
# finished
# total time:  438
# accuracy for vid:  test07.mp4  is :  0.5634615384615385
# Eval video:  test08.mp4  ...
# finished
# total time:  176
# accuracy for vid:  test08.mp4  is :  0.7720090293453724
# Eval video:  test09.mp4  ...
# finished
# total time:  269
# accuracy for vid:  test09.mp4  is :  0.7286821705426356
# Eval video:  test10.mp4  ...
# finished
# total time:  231
# accuracy for vid:  test10.mp4  is :  0.7306338028169014
# Eval video:  test11.mp4  ...
# finished
# total time:  201
# accuracy for vid:  test11.mp4  is :  0.7543859649122807
# Eval video:  test12.mp4  ...
# finished
# total time:  157
# accuracy for vid:  test12.mp4  is :  0.8081841432225064
# Eval video:  test13.mp4  ...
# finished
# total time:  239
# accuracy for vid:  test13.mp4  is :  0.7967625899280576
# Eval video:  test14.mp4  ...
# finished
# total time:  163
# accuracy for vid:  test14.mp4  is :  0.7791878172588832
# Eval video:  test15.mp4  ...
# finished
# total time:  215
# accuracy for vid:  test15.mp4  is :  0.75
# Eval video:  test16.mp4  ...
# finished
# total time:  300
# accuracy for vid:  test16.mp4  is :  0.6964809384164223
# Eval video:  test17.mp4  ...
# finished
# total time:  206
# accuracy for vid:  test17.mp4  is :  0.6986301369863014
# Eval video:  test18.mp4  ...
# finished
# total time:  281
# accuracy for vid:  test18.mp4  is :  0.6938483547925608
# Eval video:  test19.mp4  ...
# finished
# total time:  293
# accuracy for vid:  test19.mp4  is :  0.7336065573770492
# Eval video:  test20.mp4  ...
# finished
# total time:  221
# accuracy for vid:  test20.mp4  is :  0.7771535580524345
# Eval video:  test21.mp4  ...
# finished
# total time:  193
# accuracy for vid:  test21.mp4  is :  0.8166666666666667
# Eval video:  test22.mp4  ...
# finished
# total time:  205
# accuracy for vid:  test22.mp4  is :  0.7342799188640974
# Eval video:  test23.mp4  ...
# finished
# total time:  210
# accuracy for vid:  test23.mp4  is :  0.8275862068965517
# Eval video:  test24.mp4  ...
# finished
# total time:  214
# accuracy for vid:  test24.mp4  is :  0.7732558139534884
# Eval video:  test25.mp4  ...
# finished
# total time:  246
# accuracy for vid:  test25.mp4  is :  0.6830508474576271

# %%
cur_time = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+"_result"
os.mkdir(cur_time)
for i in os.listdir("/data/disk/LUO/cataract_test_video"):
    main(i,cur_time,threshold=0.15,num_fill=28)
# Out:
# Eval video:  test01.mp4  ...
# finished
# total time:  299
# accuracy for vid:  test01.mp4  is :  0.7184594953519257
# Eval video:  test02.mp4  ...
# finished
# total time:  739
# accuracy for vid:  test02.mp4  is :  0.5129310344827587
# Eval video:  test03.mp4  ...
# finished
# total time:  201
# accuracy for vid:  test03.mp4  is :  0.8449304174950298
# Eval video:  test04.mp4  ...
# finished
# total time:  188
# accuracy for vid:  test04.mp4  is :  0.7784679089026915
# Eval video:  test05.mp4  ...
# finished
# total time:  184
# accuracy for vid:  test05.mp4  is :  0.7547974413646056
# Eval video:  test06.mp4  ...
# finished
# total time:  231
# accuracy for vid:  test06.mp4  is :  0.6831858407079646
# Eval video:  test07.mp4  ...
# finished
# total time:  435
# accuracy for vid:  test07.mp4  is :  0.5663461538461538
# Eval video:  test08.mp4  ...
# finished
# total time:  185
# accuracy for vid:  test08.mp4  is :  0.7539503386004515
# Eval video:  test09.mp4  ...
# finished
# total time:  268
# accuracy for vid:  test09.mp4  is :  0.7286821705426356
# Eval video:  test10.mp4  ...
# finished
# total time:  241
# accuracy for vid:  test10.mp4  is :  0.7341549295774648
# Eval video:  test11.mp4  ...
# finished
# total time:  221
# accuracy for vid:  test11.mp4  is :  0.7524366471734892
# Eval video:  test12.mp4  ...
# finished
# total time:  164
# accuracy for vid:  test12.mp4  is :  0.7979539641943734
# Eval video:  test13.mp4  ...
# finished
# total time:  236
# accuracy for vid:  test13.mp4  is :  0.8057553956834532
# Eval video:  test14.mp4  ...
# finished
# total time:  164
# accuracy for vid:  test14.mp4  is :  0.7563451776649747
# Eval video:  test15.mp4  ...
# finished
# total time:  206
# accuracy for vid:  test15.mp4  is :  0.7706611570247934
# Eval video:  test16.mp4  ...
# finished
# total time:  280
# accuracy for vid:  test16.mp4  is :  0.6862170087976539
# Eval video:  test17.mp4  ...
# finished
# total time:  218
# accuracy for vid:  test17.mp4  is :  0.6927592954990215
# Eval video:  test18.mp4  ...
# finished
# total time:  292
# accuracy for vid:  test18.mp4  is :  0.7010014306151645
# Eval video:  test19.mp4  ...
# finished
# total time:  302
# accuracy for vid:  test19.mp4  is :  0.73224043715847
# Eval video:  test20.mp4  ...
# finished
# total time:  221
# accuracy for vid:  test20.mp4  is :  0.799625468164794
# Eval video:  test21.mp4  ...
# finished
# total time:  189
# accuracy for vid:  test21.mp4  is :  0.8083333333333333
# Eval video:  test22.mp4  ...
# finished
# total time:  201
# accuracy for vid:  test22.mp4  is :  0.7200811359026369
# Eval video:  test23.mp4  ...
# finished
# total time:  202
# accuracy for vid:  test23.mp4  is :  0.8199233716475096
# Eval video:  test24.mp4  ...
# finished
# total time:  209
# accuracy for vid:  test24.mp4  is :  0.7751937984496124
# Eval video:  test25.mp4  ...
# finished
# total time:  241
# accuracy for vid:  test25.mp4  is :  0.6694915254237288

# %%
cur_time = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+"_result"
os.mkdir(cur_time)
for i in os.listdir("/data/disk/LUO/cataract_test_video"):
    main(i,cur_time,threshold=0.15,num_fill=36)
# Out:
# Eval video:  test01.mp4  ...
# finished
# total time:  314
# accuracy for vid:  test01.mp4  is :  0.7237715803452855
# Eval video:  test02.mp4  ...
# finished
# total time:  789
# accuracy for vid:  test02.mp4  is :  0.5021551724137931
# Eval video:  test03.mp4  ...
# finished
# total time:  205
# accuracy for vid:  test03.mp4  is :  0.8608349900596421
# Eval video:  test04.mp4  ...
# finished
# total time:  203
# accuracy for vid:  test04.mp4  is :  0.7950310559006211
# Eval video:  test05.mp4  ...
# finished
# total time:  187
# accuracy for vid:  test05.mp4  is :  0.7611940298507462
# Eval video:  test06.mp4  ...
# finished
# total time:  239
# accuracy for vid:  test06.mp4  is :  0.7150442477876107
# Eval video:  test07.mp4  ...
# finished
# total time:  422
# accuracy for vid:  test07.mp4  is :  0.5682692307692307
# Eval video:  test08.mp4  ...
# finished
# total time:  179
# accuracy for vid:  test08.mp4  is :  0.8103837471783296
# Eval video:  test09.mp4  ...
# finished
# total time:  269
# accuracy for vid:  test09.mp4  is :  0.737984496124031
# Eval video:  test10.mp4  ...
# finished
# total time:  236
# accuracy for vid:  test10.mp4  is :  0.7411971830985915
# Eval video:  test11.mp4  ...
# finished
# total time:  212
# accuracy for vid:  test11.mp4  is :  0.7738791423001949
# Eval video:  test12.mp4  ...
# finished
# total time:  159
# accuracy for vid:  test12.mp4  is :  0.8388746803069054
# Eval video:  test13.mp4  ...
# finished
# total time:  228
# accuracy for vid:  test13.mp4  is :  0.8093525179856115
# Eval video:  test14.mp4  ...
# finished
# total time:  158
# accuracy for vid:  test14.mp4  is :  0.7944162436548223
# Eval video:  test15.mp4  ...
# finished
# total time:  197
# accuracy for vid:  test15.mp4  is :  0.7582644628099173
# Eval video:  test16.mp4  ...
# finished
# total time:  302
# accuracy for vid:  test16.mp4  is :  0.7052785923753666
# Eval video:  test17.mp4  ...
# finished
# total time:  213
# accuracy for vid:  test17.mp4  is :  0.7299412915851272
# Eval video:  test18.mp4  ...
# finished
# total time:  280
# accuracy for vid:  test18.mp4  is :  0.7167381974248928
# Eval video:  test19.mp4  ...
# finished
# total time:  290
# accuracy for vid:  test19.mp4  is :  0.75
# Eval video:  test20.mp4  ...
# finished
# total time:  207
# accuracy for vid:  test20.mp4  is :  0.7827715355805244
# Eval video:  test21.mp4  ...
# finished
# total time:  195
# accuracy for vid:  test21.mp4  is :  0.8354166666666667
# Eval video:  test22.mp4  ...
# finished
# total time:  198
# accuracy for vid:  test22.mp4  is :  0.7281947261663286
# Eval video:  test23.mp4  ...
# finished
# total time:  213
# accuracy for vid:  test23.mp4  is :  0.8275862068965517
# Eval video:  test24.mp4  ...
# finished
# total time:  211
# accuracy for vid:  test24.mp4  is :  0.7790697674418605
# Eval video:  test25.mp4  ...
# finished
# total time:  234
# accuracy for vid:  test25.mp4  is :  0.6983050847457627

# %%
cur_time = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+"_result"
os.mkdir(cur_time)
for i in os.listdir("/data/disk/LUO/cataract_test_video"):
    main(i,cur_time,threshold=0.15,num_fill=40)
# Out:
# Eval video:  test01.mp4  ...
# finished
# total time:  303
# accuracy for vid:  test01.mp4  is :  0.7197875166002656
# Eval video:  test02.mp4  ...
# finished
# total time:  765
# accuracy for vid:  test02.mp4  is :  0.5026939655172413
# Eval video:  test03.mp4  ...
# finished
# total time:  207
# accuracy for vid:  test03.mp4  is :  0.8628230616302187
# Eval video:  test04.mp4  ...
# finished
# total time:  195
# accuracy for vid:  test04.mp4  is :  0.7867494824016563
# Eval video:  test05.mp4  ...
# finished
# total time:  188
# accuracy for vid:  test05.mp4  is :  0.767590618336887
# Eval video:  test06.mp4  ...
# finished
# total time:  228
# accuracy for vid:  test06.mp4  is :  0.7380530973451327
# Eval video:  test07.mp4  ...
# finished
# total time:  402
# accuracy for vid:  test07.mp4  is :  0.5769230769230769
# Eval video:  test08.mp4  ...
# finished
# total time:  174
# accuracy for vid:  test08.mp4  is :  0.8261851015801355
# Eval video:  test09.mp4  ...
# finished
# total time:  261
# accuracy for vid:  test09.mp4  is :  0.7441860465116279
# Eval video:  test10.mp4  ...
# finished
# total time:  225
# accuracy for vid:  test10.mp4  is :  0.7552816901408451
# Eval video:  test11.mp4  ...
# finished
# total time:  200
# accuracy for vid:  test11.mp4  is :  0.7680311890838206
# Eval video:  test12.mp4  ...
# finished
# total time:  154
# accuracy for vid:  test12.mp4  is :  0.8491048593350383
# Eval video:  test13.mp4  ...
# finished
# total time:  219
# accuracy for vid:  test13.mp4  is :  0.8165467625899281
# Eval video:  test14.mp4  ...
# finished
# total time:  154
# accuracy for vid:  test14.mp4  is :  0.8045685279187818
# Eval video:  test15.mp4  ...
# finished
# total time:  186
# accuracy for vid:  test15.mp4  is :  0.7644628099173554
# Eval video:  test16.mp4  ...
# finished
# total time:  273
# accuracy for vid:  test16.mp4  is :  0.7052785923753666
# Eval video:  test17.mp4  ...
# finished
# total time:  181
# accuracy for vid:  test17.mp4  is :  0.7514677103718199
# Eval video:  test18.mp4  ...
# finished
# total time:  249
# accuracy for vid:  test18.mp4  is :  0.7181688125894135
# Eval video:  test19.mp4  ...
# finished
# total time:  273
# accuracy for vid:  test19.mp4  is :  0.7540983606557377
# Eval video:  test20.mp4  ...
# finished
# total time:  186
# accuracy for vid:  test20.mp4  is :  0.7865168539325843
# Eval video:  test21.mp4  ...
# finished
# total time:  172
# accuracy for vid:  test21.mp4  is :  0.8520833333333333
# Eval video:  test22.mp4  ...
# finished
# total time:  181
# accuracy for vid:  test22.mp4  is :  0.7342799188640974
# Eval video:  test23.mp4  ...
# finished
# total time:  186
# accuracy for vid:  test23.mp4  is :  0.8295019157088123
# Eval video:  test24.mp4  ...
# finished
# total time:  193
# accuracy for vid:  test24.mp4  is :  0.7810077519379846
# Eval video:  test25.mp4  ...
# finished
# total time:  212
# accuracy for vid:  test25.mp4  is :  0.6966101694915254

# %%
cur_time = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+"_result"
os.mkdir(cur_time)
for i in os.listdir("/data/disk/LUO/cataract_test_video"):
    main(i,cur_time,threshold=0.165,num_fill=32)
# Out:
# Eval video:  test01.mp4  ...
# finished
# total time:  277
# accuracy for vid:  test01.mp4  is :  0.6759628154050464
# Eval video:  test02.mp4  ...
# finished
# total time:  675
# accuracy for vid:  test02.mp4  is :  0.5
# Eval video:  test03.mp4  ...
# finished
# total time:  185
# accuracy for vid:  test03.mp4  is :  0.8588469184890656
# Eval video:  test04.mp4  ...
# finished
# total time:  174
# accuracy for vid:  test04.mp4  is :  0.7991718426501035
# Eval video:  test05.mp4  ...
# finished
# total time:  174
# accuracy for vid:  test05.mp4  is :  0.7718550106609808
# Eval video:  test06.mp4  ...
# finished
# total time:  206
# accuracy for vid:  test06.mp4  is :  0.7044247787610619
# Eval video:  test07.mp4  ...
# finished
# total time:  368
# accuracy for vid:  test07.mp4  is :  0.573076923076923
# Eval video:  test08.mp4  ...
# finished
# total time:  166
# accuracy for vid:  test08.mp4  is :  0.7900677200902935
# Eval video:  test09.mp4  ...
# finished
# total time:  235
# accuracy for vid:  test09.mp4  is :  0.7488372093023256
# Eval video:  test10.mp4  ...
# finished
# total time:  200
# accuracy for vid:  test10.mp4  is :  0.7429577464788732
# Eval video:  test11.mp4  ...
# finished
# total time:  186
# accuracy for vid:  test11.mp4  is :  0.7660818713450293
# Eval video:  test12.mp4  ...
# finished
# total time:  132
# accuracy for vid:  test12.mp4  is :  0.8312020460358056
# Eval video:  test13.mp4  ...
# finished
# total time:  208
# accuracy for vid:  test13.mp4  is :  0.802158273381295
# Eval video:  test14.mp4  ...
# finished
# total time:  142
# accuracy for vid:  test14.mp4  is :  0.7817258883248731
# Eval video:  test15.mp4  ...
# finished
# total time:  170
# accuracy for vid:  test15.mp4  is :  0.762396694214876
# Eval video:  test16.mp4  ...
# finished
# total time:  245
# accuracy for vid:  test16.mp4  is :  0.7023460410557185
# Eval video:  test17.mp4  ...
# finished
# total time:  184
# accuracy for vid:  test17.mp4  is :  0.7181996086105675
# Eval video:  test18.mp4  ...
# finished
# total time:  250
# accuracy for vid:  test18.mp4  is :  0.7224606580829757
# Eval video:  test19.mp4  ...
# finished
# total time:  264
# accuracy for vid:  test19.mp4  is :  0.7390710382513661
# Eval video:  test20.mp4  ...
# finished
# total time:  194
# accuracy for vid:  test20.mp4  is :  0.7808988764044944
# Eval video:  test21.mp4  ...
# finished
# total time:  168
# accuracy for vid:  test21.mp4  is :  0.825
# Eval video:  test22.mp4  ...
# finished
# total time:  182
# accuracy for vid:  test22.mp4  is :  0.7079107505070994
# Eval video:  test23.mp4  ...
# finished
# total time:  186
# accuracy for vid:  test23.mp4  is :  0.8237547892720306
# Eval video:  test24.mp4  ...
# finished
# total time:  188
# accuracy for vid:  test24.mp4  is :  0.7674418604651163
# Eval video:  test25.mp4  ...
# finished
# total time:  215
# accuracy for vid:  test25.mp4  is :  0.6932203389830508

# %%
cur_time = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+"_result"
os.mkdir(cur_time)
for i in os.listdir("/data/disk/LUO/cataract_test_video"):
    main(i,cur_time,threshold=0.165,num_fill=40)
# Out:
# Eval video:  test01.mp4  ...
# finished
# total time:  264
# accuracy for vid:  test01.mp4  is :  0.6613545816733067
# Eval video:  test02.mp4  ...
# finished
# total time:  683
# accuracy for vid:  test02.mp4  is :  0.4978448275862069
# Eval video:  test03.mp4  ...
# finished
# total time:  179
# accuracy for vid:  test03.mp4  is :  0.8667992047713717
# Eval video:  test04.mp4  ...
# finished
# total time:  174
# accuracy for vid:  test04.mp4  is :  0.7991718426501035
# Eval video:  test05.mp4  ...
# finished
# total time:  165
# accuracy for vid:  test05.mp4  is :  0.7654584221748401
# Eval video:  test06.mp4  ...
# finished
# total time:  208
# accuracy for vid:  test06.mp4  is :  0.7451327433628319
# Eval video:  test07.mp4  ...
# finished
# total time:  380
# accuracy for vid:  test07.mp4  is :  0.5798076923076924
# Eval video:  test08.mp4  ...
# finished
# total time:  159
# accuracy for vid:  test08.mp4  is :  0.8397291196388262
# Eval video:  test09.mp4  ...
# finished
# total time:  233
# accuracy for vid:  test09.mp4  is :  0.7503875968992249
# Eval video:  test10.mp4  ...
# finished
# total time:  209
# accuracy for vid:  test10.mp4  is :  0.7676056338028169
# Eval video:  test11.mp4  ...
# finished
# total time:  185
# accuracy for vid:  test11.mp4  is :  0.7719298245614035
# Eval video:  test12.mp4  ...
# finished
# total time:  146
# accuracy for vid:  test12.mp4  is :  0.8593350383631714
# Eval video:  test13.mp4  ...
# finished
# total time:  200
# accuracy for vid:  test13.mp4  is :  0.8237410071942446
# Eval video:  test14.mp4  ...
# finished
# total time:  146
# accuracy for vid:  test14.mp4  is :  0.8121827411167513
# Eval video:  test15.mp4  ...
# finished
# total time:  177
# accuracy for vid:  test15.mp4  is :  0.7665289256198347
# Eval video:  test16.mp4  ...
# finished
# total time:  255
# accuracy for vid:  test16.mp4  is :  0.7067448680351907
# Eval video:  test17.mp4  ...
# finished
# total time:  193
# accuracy for vid:  test17.mp4  is :  0.7632093933463796
# Eval video:  test18.mp4  ...
# finished
# total time:  288
# accuracy for vid:  test18.mp4  is :  0.7310443490701002
# Eval video:  test19.mp4  ...
# finished
# total time:  301
# accuracy for vid:  test19.mp4  is :  0.7581967213114754
# Eval video:  test20.mp4  ...
# finished
# total time:  218
# accuracy for vid:  test20.mp4  is :  0.7902621722846442
# Eval video:  test21.mp4  ...
# finished
# total time:  192
# accuracy for vid:  test21.mp4  is :  0.8604166666666667
# Eval video:  test22.mp4  ...
# finished
# total time:  191
# accuracy for vid:  test22.mp4  is :  0.7139959432048681
# Eval video:  test23.mp4  ...
# finished
# total time:  212
# accuracy for vid:  test23.mp4  is :  0.8352490421455939
# Eval video:  test24.mp4  ...
# finished
# total time:  203
# accuracy for vid:  test24.mp4  is :  0.7732558139534884
# Eval video:  test25.mp4  ...
# finished
# total time:  235
# accuracy for vid:  test25.mp4  is :  0.7101694915254237

# %%
cur_time = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+"_result"
os.mkdir(cur_time)
for i in os.listdir("/data/disk/LUO/cataract_test_video"):
    main(i,cur_time,threshold=0.13,num_fill=42)
# Out:
# Eval video:  test01.mp4  ...
# finished
# total time:  311
# accuracy for vid:  test01.mp4  is :  0.7237715803452855
# Eval video:  test02.mp4  ...
# finished
# total time:  780
# accuracy for vid:  test02.mp4  is :  0.5005387931034483
# Eval video:  test03.mp4  ...
# finished
# total time:  197
# accuracy for vid:  test03.mp4  is :  0.8369781312127237
# Eval video:  test04.mp4  ...
# finished
# total time:  190
# accuracy for vid:  test04.mp4  is :  0.7929606625258799
# Eval video:  test05.mp4  ...
# finished
# total time:  184
# accuracy for vid:  test05.mp4  is :  0.7611940298507462
# Eval video:  test06.mp4  ...
# finished
# total time:  223
# accuracy for vid:  test06.mp4  is :  0.7097345132743362
# Eval video:  test07.mp4  ...
# finished
# total time:  417
# accuracy for vid:  test07.mp4  is :  0.5855769230769231
# Eval video:  test08.mp4  ...
# finished
# total time:  179
# accuracy for vid:  test08.mp4  is :  0.8171557562076749
# Eval video:  test09.mp4  ...
# finished
# total time:  257
# accuracy for vid:  test09.mp4  is :  0.7286821705426356
# Eval video:  test10.mp4  ...
# finished
# total time:  224
# accuracy for vid:  test10.mp4  is :  0.7535211267605634
# Eval video:  test11.mp4  ...
# finished
# total time:  197
# accuracy for vid:  test11.mp4  is :  0.7543859649122807
# Eval video:  test12.mp4  ...
# finished
# total time:  151
# accuracy for vid:  test12.mp4  is :  0.8465473145780051
# Eval video:  test13.mp4  ...
# finished
# total time:  211
# accuracy for vid:  test13.mp4  is :  0.8075539568345323
# Eval video:  test14.mp4  ...
# finished
# total time:  155
# accuracy for vid:  test14.mp4  is :  0.7868020304568528
# Eval video:  test15.mp4  ...
# finished
# total time:  196
# accuracy for vid:  test15.mp4  is :  0.743801652892562
# Eval video:  test16.mp4  ...
# finished
# total time:  275
# accuracy for vid:  test16.mp4  is :  0.7067448680351907
# Eval video:  test17.mp4  ...
# finished
# total time:  209
# accuracy for vid:  test17.mp4  is :  0.7221135029354208
# Eval video:  test18.mp4  ...
# finished
# total time:  273
# accuracy for vid:  test18.mp4  is :  0.7052932761087267
# Eval video:  test19.mp4  ...
# finished
# total time:  300
# accuracy for vid:  test19.mp4  is :  0.7418032786885246
# Eval video:  test20.mp4  ...
# finished
# total time:  207
# accuracy for vid:  test20.mp4  is :  0.7883895131086143
# Eval video:  test21.mp4  ...
# finished
# total time:  195
# accuracy for vid:  test21.mp4  is :  0.8479166666666667
# Eval video:  test22.mp4  ...
# finished
# total time:  201
# accuracy for vid:  test22.mp4  is :  0.7647058823529411
# Eval video:  test23.mp4  ...
# finished
# total time:  210
# accuracy for vid:  test23.mp4  is :  0.8314176245210728
# Eval video:  test24.mp4  ...
# finished
# total time:  218
# accuracy for vid:  test24.mp4  is :  0.7751937984496124
# Eval video:  test25.mp4  ...
# finished
# total time:  233
# accuracy for vid:  test25.mp4  is :  0.7016949152542373

# %%
def main(vid,log_folder,threshold=0.1,num_fill=32):    
    print("Eval video: ",vid," ...")
    vid_path = os.path.join(dir_name,vid)
    device = "cuda:4"
    cap = cv2.VideoCapture(vid_path)
    sample_height = 256
    sample_width = 256
    count = 0
    seq_length = 32
    queue = deque(maxlen=32)
    ret = True
    frame_wise_feature = None
    idx = int(vid_path.split("/")[-1].split(".")[0].split("test")[-1])-1 #test01 -> 0
    dict_db,label_dict = _load_json() #dict_db contains segments and labels
    current_db = dict_db[idx] #current test file json
    count_2 = 0 #count after queue is full
    # load tridet model
    # not ideal for multi GPU training, ok for now

    # load ckpt, reset epoch / best rmse


    pred_list = []
    score_list = []
    start = datetime.datetime.now()
    while ret:
        #print("count: ",count)
        
        ret,frame = cap.read()
        if not ret:
            print("finished")
            break
        height, width = frame.shape[:2]
        frame = cv2.resize(frame,(sample_height,sample_width),interpolation = cv2.INTER_LINEAR)
        queue.append(frame)
        if count<32:
            count+=1
            continue
        else:
            
            frames = np.stack(queue, axis=0)
            frames = pre_process_frame(frames)
            frame_list = pack_pathway_output(cfg, frames) #得到一个list,list[0]为(3,8,256,256),[1]为[3,32,256,256]分别表示slow和fast两条线
            frame_list[0] = frame_list[0].unsqueeze(0) #增加一个batch维度
            frame_list[1] = frame_list[1].unsqueeze(0)
            if count_2%30 == 0: #每30表示的是每30个frame，即每一秒取一次feature
                cur_second = count//30
                #print("current second: ",cur_second)
                if frame_wise_feature is None:
                    frame_wise_feature = test(extract_model,cfg,frame_list) #得到每32个frame为单位的一个feature，size大小为(1,2304)
                    #print("frame_wise_feture",frame_wise_feture.shape)
                    #print(test(cfg,frame_list))
                else:
                    #print("frame_wise_feture ",frame_wise_feture.shape)
                    cur_feature = test(extract_model,cfg,frame_list)
                    #print("cur_feature ",cur_feature.shape)
                    frame_wise_feature = np.concatenate((frame_wise_feature,cur_feature),axis=0)
                    #print(frame_wise_feture.shape)
                    #将frame_wise_feature 在dim 0 上concate起来，放入surgplan的eval方程
                
                
                #transfer input frame_wise_features into dictionary
                inputs = getitem(data_list=dict_db,features=frame_wise_feature, idx=idx,num_frames=len(frame_wise_feature))
                #ret = False
                #inference
                results = valid_one_epoch([mirror_feature(inputs,num_fill)],model=model)
                df = to_df(results)
                if inputs["feats"].size(1) >= 1024:
                    pred_label,score = get_middle_label(df,[512-num_fill//2,512+num_fill//2],threshold)
                else:
                    pred_label,score = get_middle_label(df,[cur_second+num_fill-2,cur_second+num_fill],threshold)
                #print("predicted label: ",pred_label," score:",score)
                pred_list.append(pred_label)
                score_list.append(score)
            count+=1
            count_2 +=1 
    end = datetime.datetime.now()
    cap.release()
    print("total time: ", (end-start).seconds)
    acc = accuracy_score(gt[gt["video_id"]==vid]["gt_labels"][-len(pred_list):],pred_list[:])
    print("accuracy for vid: ",vid," is : ",acc)
    
    x = gt[gt["video_id"]==vid][-len(pred_list):]
    x["pred_labels"] = pred_list
    x["pred_scores"] = score_list

    csv_file = "./"+log_folder+"/result_real_time_"+vid+".csv"
    x.to_csv(csv_file)

# %%
cur_time = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+"_result"
print(cur_time)
os.mkdir(cur_time)
for i in os.listdir("/data/disk/LUO/cataract_test_video"):
    main(i,cur_time,threshold=0.13,num_fill=42)
# Out:
# 2024-02-01-12-03-06_result
# Eval video:  test01.mp4  ...
# finished
# total time:  319
# accuracy for vid:  test01.mp4  is :  0.7237715803452855
# Eval video:  test02.mp4  ...
# finished
# total time:  763
# accuracy for vid:  test02.mp4  is :  0.5005387931034483
# Eval video:  test03.mp4  ...
# finished
# total time:  209
# accuracy for vid:  test03.mp4  is :  0.8369781312127237
# Eval video:  test04.mp4  ...
# finished
# total time:  204
# accuracy for vid:  test04.mp4  is :  0.7929606625258799
# Eval video:  test05.mp4  ...
# finished
# total time:  186
# accuracy for vid:  test05.mp4  is :  0.7611940298507462
# Eval video:  test06.mp4  ...
# finished
# total time:  235
# accuracy for vid:  test06.mp4  is :  0.7097345132743362
# Eval video:  test07.mp4  ...
# finished
# total time:  426
# accuracy for vid:  test07.mp4  is :  0.5855769230769231
# Eval video:  test08.mp4  ...
# finished
# total time:  183
# accuracy for vid:  test08.mp4  is :  0.8171557562076749
# Eval video:  test09.mp4  ...
# finished
# total time:  258
# accuracy for vid:  test09.mp4  is :  0.7286821705426356
# Eval video:  test10.mp4  ...
# finished
# total time:  232
# accuracy for vid:  test10.mp4  is :  0.7535211267605634
# Eval video:  test11.mp4  ...
# finished
# total time:  213
# accuracy for vid:  test11.mp4  is :  0.7543859649122807
# Eval video:  test12.mp4  ...
# finished
# total time:  157
# accuracy for vid:  test12.mp4  is :  0.8465473145780051
# Eval video:  test13.mp4  ...
# finished
# total time:  224
# accuracy for vid:  test13.mp4  is :  0.8075539568345323
# Eval video:  test14.mp4  ...
# finished
# total time:  160
# accuracy for vid:  test14.mp4  is :  0.7868020304568528
# Eval video:  test15.mp4  ...
# finished
# total time:  196
# accuracy for vid:  test15.mp4  is :  0.743801652892562
# Eval video:  test16.mp4  ...
# finished
# total time:  277
# accuracy for vid:  test16.mp4  is :  0.7067448680351907
# Eval video:  test17.mp4  ...
# finished
# total time:  205
# accuracy for vid:  test17.mp4  is :  0.7221135029354208
# Eval video:  test18.mp4  ...
# finished
# total time:  287
# accuracy for vid:  test18.mp4  is :  0.7052932761087267
# Eval video:  test19.mp4  ...
# finished
# total time:  290
# accuracy for vid:  test19.mp4  is :  0.7418032786885246
# Eval video:  test20.mp4  ...
# finished
# total time:  212
# accuracy for vid:  test20.mp4  is :  0.7883895131086143
# Eval video:  test21.mp4  ...
# finished
# total time:  211
# accuracy for vid:  test21.mp4  is :  0.8479166666666667
# Eval video:  test22.mp4  ...
# finished
# total time:  226
# accuracy for vid:  test22.mp4  is :  0.7647058823529411
# Eval video:  test23.mp4  ...
# finished
# total time:  237
# accuracy for vid:  test23.mp4  is :  0.8314176245210728
# Eval video:  test24.mp4  ...
# finished
# total time:  238
# accuracy for vid:  test24.mp4  is :  0.7751937984496124
# Eval video:  test25.mp4  ...
# finished
# total time:  281
# accuracy for vid:  test25.mp4  is :  0.7016949152542373

# %%
cur_time = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+"_result"
print(cur_time)
os.mkdir(cur_time)
for i in os.listdir("/data/disk/LUO/cataract_test_video"):
    main(i,cur_time,threshold=0.1,num_fill=40)
# Out:
# 2024-02-01-13-50-27_result
# Eval video:  test01.mp4  ...
# finished
# total time:  393
# accuracy for vid:  test01.mp4  is :  0.7184594953519257
# Eval video:  test02.mp4  ...
# finished
# total time:  966
# accuracy for vid:  test02.mp4  is :  0.47413793103448276
# Eval video:  test03.mp4  ...
# finished
# total time:  267
# accuracy for vid:  test03.mp4  is :  0.8170974155069582
# Eval video:  test04.mp4  ...
# finished
# total time:  241
# accuracy for vid:  test04.mp4  is :  0.7784679089026915
# Eval video:  test05.mp4  ...
# finished
# total time:  228
# accuracy for vid:  test05.mp4  is :  0.7313432835820896
# Eval video:  test06.mp4  ...
# finished
# total time:  265
# accuracy for vid:  test06.mp4  is :  0.6814159292035398
# Eval video:  test07.mp4  ...
# finished
# total time:  518
# accuracy for vid:  test07.mp4  is :  0.5855769230769231
# Eval video:  test08.mp4  ...
# finished
# total time:  226
# accuracy for vid:  test08.mp4  is :  0.7765237020316027
# Eval video:  test09.mp4  ...
# finished
# total time:  321
# accuracy for vid:  test09.mp4  is :  0.7147286821705426
# Eval video:  test10.mp4  ...
# finished
# total time:  299
# accuracy for vid:  test10.mp4  is :  0.7376760563380281
# Eval video:  test11.mp4  ...
# finished
# total time:  561
# accuracy for vid:  test11.mp4  is :  0.7407407407407407
# Eval video:  test12.mp4  ...
# finished
# total time:  415
# accuracy for vid:  test12.mp4  is :  0.8209718670076727
# Eval video:  test13.mp4  ...
# finished
# total time:  647
# accuracy for vid:  test13.mp4  is :  0.7464028776978417
# Eval video:  test14.mp4  ...
# finished
# total time:  449
# accuracy for vid:  test14.mp4  is :  0.748730964467005
# Eval video:  test15.mp4  ...
# finished
# total time:  553
# accuracy for vid:  test15.mp4  is :  0.7231404958677686
# Eval video:  test16.mp4  ...
# finished
# total time:  762
# accuracy for vid:  test16.mp4  is :  0.6847507331378299
# Eval video:  test17.mp4  ...
# finished
# total time:  592
# accuracy for vid:  test17.mp4  is :  0.6947162426614482
# Eval video:  test18.mp4  ...
# finished
# total time:  782
# accuracy for vid:  test18.mp4  is :  0.6881258941344778
# Eval video:  test19.mp4  ...
# finished
# total time:  844
# accuracy for vid:  test19.mp4  is :  0.7363387978142076
# Eval video:  test20.mp4  ...
# finished
# total time:  614
# accuracy for vid:  test20.mp4  is :  0.7790262172284644
# Eval video:  test21.mp4  ...
# finished
# total time:  606
# accuracy for vid:  test21.mp4  is :  0.8208333333333333
# Eval video:  test22.mp4  ...
# finished
# total time:  593
# accuracy for vid:  test22.mp4  is :  0.7464503042596349
# Eval video:  test23.mp4  ...
# finished
# total time:  619
# accuracy for vid:  test23.mp4  is :  0.8295019157088123
# Eval video:  test24.mp4  ...
# finished
# total time:  664
# accuracy for vid:  test24.mp4  is :  0.7810077519379846
# Eval video:  test25.mp4  ...
# finished
# total time:  768
# accuracy for vid:  test25.mp4  is :  0.6864406779661016

# %%
cur_time = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+"_result"
print(cur_time)
os.mkdir(cur_time)
for i in os.listdir("/data/disk/LUO/cataract_test_video"):
    main(i,cur_time,threshold=0.15,num_fill=40)
# Out:
# 2024-02-01-17-30-33_result
# Eval video:  test01.mp4  ...
# finished
# total time:  1019
# accuracy for vid:  test01.mp4  is :  0.7197875166002656
# Eval video:  test02.mp4  ...
# finished
# total time:  2612
# accuracy for vid:  test02.mp4  is :  0.5026939655172413
# Eval video:  test03.mp4  ...
# finished
# total time:  651
# accuracy for vid:  test03.mp4  is :  0.8628230616302187
# Eval video:  test04.mp4  ...
# finished
# total time:  634
# accuracy for vid:  test04.mp4  is :  0.7867494824016563
# Eval video:  test05.mp4  ...
# finished
# total time:  549
# accuracy for vid:  test05.mp4  is :  0.767590618336887
# Eval video:  test06.mp4  ...
# finished
# total time:  714
# accuracy for vid:  test06.mp4  is :  0.7380530973451327
# Eval video:  test07.mp4  ...
# finished
# total time:  1418
# accuracy for vid:  test07.mp4  is :  0.5769230769230769
# Eval video:  test08.mp4  ...
# finished
# total time:  594
# accuracy for vid:  test08.mp4  is :  0.8261851015801355
# Eval video:  test09.mp4  ...
# finished
# total time:  973
# accuracy for vid:  test09.mp4  is :  0.7441860465116279
# Eval video:  test10.mp4  ...
# finished
# total time:  855
# accuracy for vid:  test10.mp4  is :  0.7552816901408451
# Eval video:  test11.mp4  ...
# finished
# total time:  672
# accuracy for vid:  test11.mp4  is :  0.7680311890838206
# Eval video:  test12.mp4  ...
# finished
# total time:  486
# accuracy for vid:  test12.mp4  is :  0.8491048593350383
# Eval video:  test13.mp4  ...
# finished
# total time:  740
# accuracy for vid:  test13.mp4  is :  0.8165467625899281
# Eval video:  test14.mp4  ...
# finished
# total time:  520
# accuracy for vid:  test14.mp4  is :  0.8045685279187818
# Eval video:  test15.mp4  ...
# finished
# total time:  601
# accuracy for vid:  test15.mp4  is :  0.7644628099173554
# Eval video:  test16.mp4  ...
# finished
# total time:  940
# accuracy for vid:  test16.mp4  is :  0.7052785923753666
# Eval video:  test17.mp4  ...
# finished
# total time:  623
# accuracy for vid:  test17.mp4  is :  0.7514677103718199
# Eval video:  test18.mp4  ...
# finished
# total time:  871
# accuracy for vid:  test18.mp4  is :  0.7181688125894135
# Eval video:  test19.mp4  ...
# finished
# total time:  966
# accuracy for vid:  test19.mp4  is :  0.7540983606557377
# Eval video:  test20.mp4  ...
# finished
# total time:  721
# accuracy for vid:  test20.mp4  is :  0.7865168539325843
# Eval video:  test21.mp4  ...
# finished
# total time:  622
# accuracy for vid:  test21.mp4  is :  0.8520833333333333
# Eval video:  test22.mp4  ...
# finished
# total time:  615
# accuracy for vid:  test22.mp4  is :  0.7342799188640974
# Eval video:  test23.mp4  ...
# finished
# total time:  688
# accuracy for vid:  test23.mp4  is :  0.8295019157088123
# Eval video:  test24.mp4  ...
# finished
# total time:  691
# accuracy for vid:  test24.mp4  is :  0.7810077519379846
# Eval video:  test25.mp4  ...
# finished
# total time:  801
# accuracy for vid:  test25.mp4  is :  0.6966101694915254

# %%
def main(vid,log_folder,threshold=0.1,num_fill=32):    
    print("Eval video: ",vid," ...")
    vid_path = os.path.join(dir_name,vid)
    device = "cuda:4"
    cap = cv2.VideoCapture(vid_path)
    sample_height = 256
    sample_width = 256
    count = 0
    seq_length = 32
    queue = deque(maxlen=32)
    ret = True
    frame_wise_feature = None
    idx = int(vid_path.split("/")[-1].split(".")[0].split("test")[-1])-1 #test01 -> 0
    dict_db,label_dict = _load_json() #dict_db contains segments and labels
    current_db = dict_db[idx] #current test file json
    count_2 = 0 #count after queue is full
    # load tridet model
    # not ideal for multi GPU training, ok for now

    # load ckpt, reset epoch / best rmse


    pred_list = []
    score_list = []
    start = datetime.datetime.now()
    while ret:
        #print("count: ",count)
        
        ret,frame = cap.read()
        if not ret:
            print("finished")
            break
        height, width = frame.shape[:2]
        frame = cv2.resize(frame,(sample_height,sample_width),interpolation = cv2.INTER_LINEAR)
        queue.append(frame)
        if count<32:
            count+=1
            continue
        else:
            
            frames = np.stack(queue, axis=0)
            frames = pre_process_frame(frames)
            frame_list = pack_pathway_output(cfg, frames) #得到一个list,list[0]为(3,8,256,256),[1]为[3,32,256,256]分别表示slow和fast两条线
            frame_list[0] = frame_list[0].unsqueeze(0) #增加一个batch维度
            frame_list[1] = frame_list[1].unsqueeze(0)
            if count_2%30 == 0: #每30表示的是每30个frame，即每一秒取一次feature
                cur_second = count//30
                #print("current second: ",cur_second)
                if frame_wise_feature is None:
                    frame_wise_feature = test(extract_model,cfg,frame_list) #得到每32个frame为单位的一个feature，size大小为(1,2304)
                    #print("frame_wise_feture",frame_wise_feture.shape)
                    #print(test(cfg,frame_list))
                else:
                    #print("frame_wise_feture ",frame_wise_feture.shape)
                    cur_feature = test(extract_model,cfg,frame_list)
                    #print("cur_feature ",cur_feature.shape)
                    frame_wise_feature = np.concatenate((frame_wise_feature,cur_feature),axis=0)
                    #print(frame_wise_feture.shape)
                    #将frame_wise_feature 在dim 0 上concate起来，放入surgplan的eval方程
                
                
                #transfer input frame_wise_features into dictionary
                inputs = getitem(data_list=dict_db,features=frame_wise_feature, idx=idx,num_frames=len(frame_wise_feature))
                #ret = False
                #inference
                results = valid_one_epoch([mirror_feature(inputs,num_fill)],model=model)
                df = to_df(results)
                if inputs["feats"].size(1) >= 1024:
                    pred_label,score = get_middle_label(df,[512-num_fill//2,512+num_fill//2],threshold)
                else:
                    pred_label,score = get_middle_label(df,[cur_second,cur_second+num_fill],threshold)
                #print("predicted label: ",pred_label," score:",score)
                pred_list.append(pred_label)
                score_list.append(score)
            count+=1
            count_2 +=1 
    end = datetime.datetime.now()
    cap.release()
    print("total time: ", (end-start).seconds)
    acc = accuracy_score(gt[gt["video_id"]==vid]["gt_labels"][-len(pred_list):],pred_list[:])
    print("accuracy for vid: ",vid," is : ",acc)
    
    x = gt[gt["video_id"]==vid][-len(pred_list):]
    x["pred_labels"] = pred_list
    x["pred_scores"] = score_list

    csv_file = "./"+log_folder+"/result_real_time_"+vid+".csv"
    x.to_csv(csv_file)

# %%
cur_time = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+"_result"
print(cur_time)
os.mkdir(cur_time)
for i in os.listdir("/data/disk/LUO/cataract_test_video"):
    main(i,cur_time,threshold=0.13,num_fill=42)
# Out:
# 2024-02-01-23-13-44_result
# Eval video:  test01.mp4  ...
# finished
# total time:  993
# accuracy for vid:  test01.mp4  is :  0.6786188579017264
# Eval video:  test02.mp4  ...
# finished
# total time:  2422
# accuracy for vid:  test02.mp4  is :  0.5032327586206896
# Eval video:  test03.mp4  ...
# finished
# total time:  652
# accuracy for vid:  test03.mp4  is :  0.7137176938369781
# Eval video:  test04.mp4  ...
# finished
# total time:  636
# accuracy for vid:  test04.mp4  is :  0.6231884057971014
# Eval video:  test05.mp4  ...
# finished
# total time:  625
# accuracy for vid:  test05.mp4  is :  0.6204690831556503
# Eval video:  test06.mp4  ...
# finished
# total time:  772
# accuracy for vid:  test06.mp4  is :  0.6070796460176991
# Eval video:  test07.mp4  ...
# finished
# total time:  1375
# accuracy for vid:  test07.mp4  is :  0.5144230769230769
# Eval video:  test08.mp4  ...
# finished
# total time:  558
# accuracy for vid:  test08.mp4  is :  0.6433408577878104
# Eval video:  test09.mp4  ...
# finished
# total time:  769
# accuracy for vid:  test09.mp4  is :  0.6852713178294574
# Eval video:  test10.mp4  ...
# finished
# total time:  719
# accuracy for vid:  test10.mp4  is :  0.6672535211267606
# Eval video:  test11.mp4  ...
# finished
# total time:  643
# accuracy for vid:  test11.mp4  is :  0.6276803118908382
# Eval video:  test12.mp4  ...
# finished
# total time:  513
# accuracy for vid:  test12.mp4  is :  0.6010230179028133
# Eval video:  test13.mp4  ...
# finished
# total time:  727
# accuracy for vid:  test13.mp4  is :  0.7086330935251799
# Eval video:  test14.mp4  ...
# finished
# total time:  510
# accuracy for vid:  test14.mp4  is :  0.6294416243654822
# Eval video:  test15.mp4  ...
# finished
# total time:  648
# accuracy for vid:  test15.mp4  is :  0.6528925619834711
# Eval video:  test16.mp4  ...
# finished
# total time:  955
# accuracy for vid:  test16.mp4  is :  0.6055718475073314
# Eval video:  test17.mp4  ...
# finished
# total time:  685
# accuracy for vid:  test17.mp4  is :  0.5870841487279843
# Eval video:  test18.mp4  ...
# finished
# total time:  906
# accuracy for vid:  test18.mp4  is :  0.6208869814020028
# Eval video:  test19.mp4  ...
# finished
# total time:  897
# accuracy for vid:  test19.mp4  is :  0.6325136612021858
# Eval video:  test20.mp4  ...
# finished
# total time:  690
# accuracy for vid:  test20.mp4  is :  0.6872659176029963
# Eval video:  test21.mp4  ...
# finished
# total time:  637
# accuracy for vid:  test21.mp4  is :  0.6708333333333333
# Eval video:  test22.mp4  ...
# finished
# total time:  651
# accuracy for vid:  test22.mp4  is :  0.6004056795131846
# Eval video:  test23.mp4  ...
# finished
# total time:  702
# accuracy for vid:  test23.mp4  is :  0.6934865900383141
# Eval video:  test24.mp4  ...
# finished
# total time:  694
# accuracy for vid:  test24.mp4  is :  0.7112403100775194
# Eval video:  test25.mp4  ...
# finished
# total time:  760
# accuracy for vid:  test25.mp4  is :  0.6016949152542372

# %%
cur_time = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+"_result"
print(cur_time)
os.mkdir(cur_time)
for i in os.listdir("/data/disk/LUO/cataract_test_video"):
    main(i,cur_time,threshold=0.1,num_fill=40)
# Out:
# 2024-02-02-04-49-33_result
# Eval video:  test01.mp4  ...
# finished
# total time:  951
# accuracy for vid:  test01.mp4  is :  0.6772908366533864
# Eval video:  test02.mp4  ...
# finished
# total time:  2369
# accuracy for vid:  test02.mp4  is :  0.47629310344827586
# Eval video:  test03.mp4  ...
# finished
# total time:  658
# accuracy for vid:  test03.mp4  is :  0.709741550695825
# Eval video:  test04.mp4  ...
# finished
# total time:  560
# accuracy for vid:  test04.mp4  is :  0.6128364389233955
# Eval video:  test05.mp4  ...
# finished
# total time:  573
# accuracy for vid:  test05.mp4  is :  0.5970149253731343
# Eval video:  test06.mp4  ...
# finished
# total time:  699
# accuracy for vid:  test06.mp4  is :  0.6070796460176991
# Eval video:  test07.mp4  ...
# finished
# total time:  1341
# accuracy for vid:  test07.mp4  is :  0.5221153846153846
# Eval video:  test08.mp4  ...
# finished
# total time:  517
# accuracy for vid:  test08.mp4  is :  0.6388261851015802
# Eval video:  test09.mp4  ...
# finished
# total time:  767
# accuracy for vid:  test09.mp4  is :  0.6713178294573643
# Eval video:  test10.mp4  ...
# finished
# total time:  723
# accuracy for vid:  test10.mp4  is :  0.6619718309859155
# Eval video:  test11.mp4  ...
# finished
# total time:  649
# accuracy for vid:  test11.mp4  is :  0.621832358674464
# Eval video:  test12.mp4  ...
# finished
# total time:  480
# accuracy for vid:  test12.mp4  is :  0.59846547314578
# Eval video:  test13.mp4  ...
# finished
# total time:  661
# accuracy for vid:  test13.mp4  is :  0.6420863309352518
# Eval video:  test14.mp4  ...
# finished
# total time:  467
# accuracy for vid:  test14.mp4  is :  0.6218274111675127
# Eval video:  test15.mp4  ...
# finished
# total time:  484
# accuracy for vid:  test15.mp4  is :  0.6549586776859504
# Eval video:  test16.mp4  ...
# finished
# total time:  360
# accuracy for vid:  test16.mp4  is :  0.5997067448680352
# Eval video:  test17.mp4  ...
# finished
# total time:  276
# accuracy for vid:  test17.mp4  is :  0.5831702544031311
# Eval video:  test18.mp4  ...
# finished
# total time:  383
# accuracy for vid:  test18.mp4  is :  0.6137339055793991
# Eval video:  test19.mp4  ...
# finished
# total time:  390
# accuracy for vid:  test19.mp4  is :  0.6311475409836066
# Eval video:  test20.mp4  ...
# finished
# total time:  305
# accuracy for vid:  test20.mp4  is :  0.6872659176029963
# Eval video:  test21.mp4  ...
# finished
# total time:  254
# accuracy for vid:  test21.mp4  is :  0.66875
# Eval video:  test22.mp4  ...
# finished
# total time:  307
# accuracy for vid:  test22.mp4  is :  0.6004056795131846
# Eval video:  test23.mp4  ...
# finished
# total time:  294
# accuracy for vid:  test23.mp4  is :  0.6934865900383141
# Eval video:  test24.mp4  ...
# finished
# total time:  267
# accuracy for vid:  test24.mp4  is :  0.7151162790697675
# Eval video:  test25.mp4  ...
# finished
# total time:  302
# accuracy for vid:  test25.mp4  is :  0.5983050847457627

# %%
cur_time = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")+"_result"
print(cur_time)
os.mkdir(cur_time)
for i in os.listdir("/data/disk/LUO/cataract_test_video"):
    main(i,cur_time,threshold=0.15,num_fill=40)
# Out:
# 2024-02-02-09-00-26_result
# Eval video:  test01.mp4  ...
# finished
# total time:  420
# accuracy for vid:  test01.mp4  is :  0.6772908366533864
# Eval video:  test02.mp4  ...
# finished
# total time:  1059
# accuracy for vid:  test02.mp4  is :  0.5053879310344828
# Eval video:  test03.mp4  ...
# finished
# total time:  293
# accuracy for vid:  test03.mp4  is :  0.7196819085487077
# Eval video:  test04.mp4  ...
# finished
# total time:  290
# accuracy for vid:  test04.mp4  is :  0.6252587991718427
# Eval video:  test05.mp4  ...
# finished
# total time:  279
# accuracy for vid:  test05.mp4  is :  0.6183368869936035
# Eval video:  test06.mp4  ...
# finished
# total time:  330
# accuracy for vid:  test06.mp4  is :  0.6212389380530974
# Eval video:  test07.mp4  ...
# finished
# total time:  617
# accuracy for vid:  test07.mp4  is :  0.5125
# Eval video:  test08.mp4  ...
# finished
# total time:  246
# accuracy for vid:  test08.mp4  is :  0.654627539503386
# Eval video:  test09.mp4  ...
# finished
# total time:  351
# accuracy for vid:  test09.mp4  is :  0.6883720930232559
# Eval video:  test10.mp4  ...
# finished
# total time:  301
# accuracy for vid:  test10.mp4  is :  0.6654929577464789
# Eval video:  test11.mp4  ...
# finished
# total time:  536
# accuracy for vid:  test11.mp4  is :  0.6179337231968811
# Eval video:  test12.mp4  ...
# finished
# total time:  469
# accuracy for vid:  test12.mp4  is :  0.6010230179028133
# Eval video:  test13.mp4  ...
# finished
# total time:  634
# accuracy for vid:  test13.mp4  is :  0.7122302158273381
# Eval video:  test14.mp4  ...
# finished
# total time:  419
# accuracy for vid:  test14.mp4  is :  0.6370558375634517
# Eval video:  test15.mp4  ...
# finished
# total time:  539
# accuracy for vid:  test15.mp4  is :  0.6611570247933884
# Eval video:  test16.mp4  ...
# finished
# total time:  837
# accuracy for vid:  test16.mp4  is :  0.5997067448680352
# Eval video:  test17.mp4  ...
# finished
# total time:  590
# accuracy for vid:  test17.mp4  is :  0.6046966731898239
# Eval video:  test18.mp4  ...
# finished
# total time:  825
# accuracy for vid:  test18.mp4  is :  0.6337625178826896
# Eval video:  test19.mp4  ...
# finished
# total time:  876
# accuracy for vid:  test19.mp4  is :  0.639344262295082
# Eval video:  test20.mp4  ...
# finished
# total time:  623
# accuracy for vid:  test20.mp4  is :  0.6872659176029963
# Eval video:  test21.mp4  ...
# finished
# total time:  590
# accuracy for vid:  test21.mp4  is :  0.6708333333333333
# Eval video:  test22.mp4  ...
# finished
# total time:  587
# accuracy for vid:  test22.mp4  is :  0.5882352941176471
# Eval video:  test23.mp4  ...
# finished
# total time:  569
# accuracy for vid:  test23.mp4  is :  0.6934865900383141
# Eval video:  test24.mp4  ...
# finished
# total time:  597
# accuracy for vid:  test24.mp4  is :  0.7151162790697675
# Eval video:  test25.mp4  ...
# finished
# total time:  683
# accuracy for vid:  test25.mp4  is :  0.5983050847457627

# %%
svrcn = pd.read_csv("/data/disk/video_detection/SVRC/experiment/20231109-233357__SGD_lr0.01_factor1.0_step5_gamma0.5_wd1e-06_noseed/result-best-8-acc72.11-f58.73-recall60.65-prec62.33-jmicro56.39/tmp_preds_gt.csv")

# %%
with open("/data/disk/LUO/test_only/r_tridet/TriDet/data/cataract/data_1102.json","r") as f:
    json_data = json.load(f)

# %%
with open("/data/disk/LUO/test_only/r_tridet/TriDet/data/cataract/data_1102_indent.json","w") as f:
    f.write(json.dumps(json_data,indent=2))

# %%
{"train24.mp4": {
    "annotation": [
      {
        "start": 11.433333333333334,
        "end": 41.233333333333334,
        "label": 1,
        "duration": 29.8,
        "subset": "training",
        "time_till_now": 41.233333333333334
      }]}}
